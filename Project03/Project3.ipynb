# %% [markdown]
# ## Web Analytics DATA 620 - Week 04 - Part 02
# ## Project 3
# ## Group - Chris Bloome / Mustafa Telab / Vinayak Kamath
# ## Date - 4th July 2021

# %% [markdown]
# Using any of the three classifiers described in chapter 6 of Natural Language Processing with Python,
# and any features you can think of, build the best name gender classifier you can.
#
# Begin by splitting the Names Corpus into three subsets: 500 words for the test set, 500 words for the devtest set, and the remaining 6900 words for the training set. Then, starting with the example name gender
# classifier, make incremental improvements. Use the dev-test set to check your progress. Once you are
# satisfied with your classifier, check its final performance on the test set.
#
# How does the performance on the test set compare to the performance on the dev-test set? Is this what
# you'd expect?
#
# Source: Natural Language Processing with Python, exercise 6.10.2

# %% [markdown]
# ## Import data

# %%
import nltk
#nltk.download('names')

# %% [markdown]
# ## Example classifier

# %% [markdown]
# Lets start with the example from the text:

# %%
def gender_features(word):
    return {'last_letter': word[-1]}

# %%
from nltk.corpus import names
import random

names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

#set seed for consistency 
random.seed(113)
random.shuffle(names)

# %%
featuresets = [(gender_features(n), g) for (n,g) in names]

test_set, dev_set, train_set = featuresets[:500],featuresets[500:1000],featuresets[1000:] 
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# function to evaluate consistently
def eval():
    {
    print(nltk.classify.accuracy(classifier, dev_set)),
    classifier.show_most_informative_features(10)           
    }
eval()
# Out:
# 0.748
# Most Informative Features
#              last_letter = 'k'              male : female =     45.1 : 1.0
#              last_letter = 'a'            female : male   =     34.4 : 1.0
#              last_letter = 'f'              male : female =     26.6 : 1.0
#              last_letter = 'v'              male : female =     15.3 : 1.0
#              last_letter = 'p'              male : female =     11.9 : 1.0
#              last_letter = 'd'              male : female =      9.0 : 1.0
#              last_letter = 'o'              male : female =      8.4 : 1.0
#              last_letter = 'z'              male : female =      7.8 : 1.0
#              last_letter = 'm'              male : female =      7.6 : 1.0
#              last_letter = 'r'              male : female =      6.5 : 1.0

# %% [markdown]
# ## Interation - Naive Bayes

# %% [markdown]
# ### Model 1

# %% [markdown]
# We will take "the kitchen sink approach" - starting with all of our features before attempting to improve our accuracy by removing parameters.
#
# At a starting value of 75%, we have a very good starting place.

# %%
def gender_features2(name):
    features = {}
    # Last Letters 
    features["last_letter"] = name[-1].lower()
    features["last_2_letters"] = name[-2:].lower()
    features["last_3_letters"] = name[-3:].lower()
    
    # First Letters 
    features["first_letter"] = name[:1].lower()
    features["first_2_letters"] = name[:2].lower()
    features["first_3_letters"] = name[:3].lower()
    
    # Values
    features["has_A"] =  "a" in name.lower()
    features["has_E"] =  "e" in name.lower()
    features["has_I"] =  "i" in name.lower()
    features["has_O"] =  "o" in name.lower()
    features["has_U"] =  "u" in name.lower()
    features["has_Y"] =  "y" in name.lower()
    
    # Other Letters 
    features["has_l"] =  "l" in name.lower()
    features["has_s"] =  "s" in name.lower()
    features["has_t"] =  "t" in name.lower()
    features["has_r"] =  "r" in name.lower()
    features["has_n"] =  "n" in name.lower()
     
    return features

# %%
featuresets = [(gender_features2(n), g) for (n,g) in names]

 
test_set, dev_set, train_set = featuresets[:500],featuresets[500:1000],featuresets[1000:] 
classifier = nltk.NaiveBayesClassifier.train(train_set)

eval()
# Out:
# 0.828
# Most Informative Features
#           last_2_letters = 'na'           female : male   =    153.1 : 1.0
#           last_2_letters = 'la'           female : male   =     70.2 : 1.0
#              last_letter = 'k'              male : female =     45.1 : 1.0
#           last_2_letters = 'us'             male : female =     39.6 : 1.0
#           last_2_letters = 'ia'           female : male   =     38.2 : 1.0
#              last_letter = 'a'            female : male   =     34.4 : 1.0
#           last_2_letters = 'sa'           female : male   =     34.2 : 1.0
#           last_2_letters = 'rd'             male : female =     30.2 : 1.0
#           last_3_letters = 'ard'            male : female =     27.7 : 1.0
#              last_letter = 'f'              male : female =     26.6 : 1.0

# %% [markdown]
# At 82.8% we have imporoved or model quite a bit.
#
# Lets asses all the features to gauge which are predictive:

# %%
classifier.show_most_informative_features(-1)
# Out:
# Most Informative Features
#           last_2_letters = 'na'           female : male   =    153.1 : 1.0
#           last_2_letters = 'la'           female : male   =     70.2 : 1.0
#              last_letter = 'k'              male : female =     45.1 : 1.0
#           last_2_letters = 'us'             male : female =     39.6 : 1.0
#           last_2_letters = 'ia'           female : male   =     38.2 : 1.0
#              last_letter = 'a'            female : male   =     34.4 : 1.0
#           last_2_letters = 'sa'           female : male   =     34.2 : 1.0
#           last_2_letters = 'rd'             male : female =     30.2 : 1.0
#           last_3_letters = 'ard'            male : female =     27.7 : 1.0
#              last_letter = 'f'              male : female =     26.6 : 1.0
#           last_3_letters = 'tta'          female : male   =     25.1 : 1.0
#           last_2_letters = 'ra'           female : male   =     24.6 : 1.0
#           last_2_letters = 'ta'           female : male   =     24.2 : 1.0
#           last_2_letters = 'ld'             male : female =     23.0 : 1.0
#           last_2_letters = 'io'             male : female =     22.8 : 1.0
#           last_2_letters = 'rt'             male : female =     20.7 : 1.0
#           last_3_letters = 'nne'          female : male   =     19.4 : 1.0
#           last_3_letters = 'old'            male : female =     18.2 : 1.0
#           last_2_letters = 'os'             male : female =     17.2 : 1.0
#          first_3_letters = 'ros'          female : male   =     16.4 : 1.0
#           last_2_letters = 'ka'           female : male   =     15.4 : 1.0
#              last_letter = 'v'              male : female =     15.3 : 1.0
#           last_3_letters = 'ita'          female : male   =     14.5 : 1.0
#           last_3_letters = 'ria'          female : male   =     13.9 : 1.0
#           last_3_letters = 'dra'          female : male   =     13.5 : 1.0
#          first_3_letters = 'tha'            male : female =     13.0 : 1.0
#           last_2_letters = 'ch'             male : female =     13.0 : 1.0
#           last_3_letters = 'ela'          female : male   =     12.2 : 1.0
#           last_3_letters = 'son'            male : female =     11.9 : 1.0
#              last_letter = 'p'              male : female =     11.9 : 1.0
#          first_3_letters = 'gar'            male : female =     11.6 : 1.0
#          first_3_letters = 'cat'          female : male   =     11.3 : 1.0
#           last_3_letters = 'nni'          female : male   =     10.9 : 1.0
#           last_3_letters = 'ert'            male : female =     10.9 : 1.0
#           last_3_letters = 'vin'            male : female =     10.9 : 1.0
#           last_2_letters = 'ip'             male : female =     10.5 : 1.0
#           last_2_letters = 'ns'             male : female =     10.5 : 1.0
#           last_2_letters = 'rn'             male : female =     10.5 : 1.0
#          first_3_letters = 'dor'          female : male   =     10.1 : 1.0
#           last_3_letters = 'dor'            male : female =      9.9 : 1.0
#           last_3_letters = 'tha'          female : male   =      9.6 : 1.0
#           last_2_letters = 'on'             male : female =      9.5 : 1.0
#          first_2_letters = 'ya'             male : female =      9.5 : 1.0
#          first_2_letters = 'tu'             male : female =      9.5 : 1.0
#           last_2_letters = 'ul'             male : female =      9.4 : 1.0
#           last_2_letters = 'ff'             male : female =      9.4 : 1.0
#           last_2_letters = 'ti'           female : male   =      9.0 : 1.0
#              last_letter = 'd'              male : female =      9.0 : 1.0
#          first_2_letters = 'wa'             male : female =      8.9 : 1.0
#          first_3_letters = 'god'            male : female =      8.8 : 1.0
#           last_2_letters = 'lo'             male : female =      8.8 : 1.0
#           last_3_letters = 'cia'          female : male   =      8.8 : 1.0
#           last_3_letters = 'isa'          female : male   =      8.8 : 1.0
#           last_2_letters = 'ya'           female : male   =      8.6 : 1.0
#              last_letter = 'o'              male : female =      8.4 : 1.0
#           last_3_letters = 'bel'          female : male   =      8.4 : 1.0
#          first_2_letters = 'fo'             male : female =      8.3 : 1.0
#           last_2_letters = 'im'             male : female =      8.3 : 1.0
#           last_2_letters = 'st'             male : female =      8.3 : 1.0
#           last_2_letters = 'as'             male : female =      8.0 : 1.0
#          first_3_letters = 'mal'          female : male   =      7.9 : 1.0
#          first_2_letters = 'ka'           female : male   =      7.8 : 1.0
#          first_3_letters = 'rod'            male : female =      7.8 : 1.0
#           last_2_letters = 'ea'           female : male   =      7.8 : 1.0
#              last_letter = 'z'              male : female =      7.8 : 1.0
#           last_3_letters = 'lan'            male : female =      7.8 : 1.0
#           last_3_letters = 'und'            male : female =      7.8 : 1.0
#           last_3_letters = 'ler'            male : female =      7.8 : 1.0
#           last_2_letters = 'em'             male : female =      7.7 : 1.0
#              last_letter = 'm'              male : female =      7.6 : 1.0
#           last_3_letters = 'lle'          female : male   =      7.6 : 1.0
#           last_3_letters = 'ine'          female : male   =      7.5 : 1.0
#           last_3_letters = 'lli'          female : male   =      7.5 : 1.0
#          first_3_letters = 'jen'          female : male   =      7.5 : 1.0
#          first_3_letters = 'arl'          female : male   =      7.5 : 1.0
#           last_2_letters = 'er'             male : female =      7.2 : 1.0
#          first_2_letters = 'wh'             male : female =      7.2 : 1.0
#           last_3_letters = 'ene'          female : male   =      7.2 : 1.0
#           last_2_letters = 'ar'             male : female =      7.1 : 1.0
#          first_2_letters = 'ty'             male : female =      7.0 : 1.0
#           last_3_letters = 'ter'            male : female =      6.9 : 1.0
#           last_2_letters = 'ro'             male : female =      6.9 : 1.0
#           last_3_letters = 'lee'          female : male   =      6.9 : 1.0
#          first_3_letters = 'nev'            male : female =      6.8 : 1.0
#          first_3_letters = 'sau'            male : female =      6.8 : 1.0
#          first_3_letters = 'bur'            male : female =      6.8 : 1.0
#          first_3_letters = 'dom'            male : female =      6.8 : 1.0
#          first_3_letters = 'nea'            male : female =      6.8 : 1.0
#          first_3_letters = 'kin'            male : female =      6.8 : 1.0
#          first_3_letters = 'mik'            male : female =      6.8 : 1.0
#          first_3_letters = 'par'            male : female =      6.8 : 1.0
#           last_3_letters = 'lon'            male : female =      6.7 : 1.0
#           last_3_letters = 'ven'            male : female =      6.7 : 1.0
#           last_3_letters = 'per'            male : female =      6.7 : 1.0
#           last_2_letters = 'te'           female : male   =      6.7 : 1.0
#          first_3_letters = 'kar'          female : male   =      6.6 : 1.0
#           last_2_letters = 'ni'           female : male   =      6.6 : 1.0
#          first_3_letters = 'bro'            male : female =      6.6 : 1.0
#          first_3_letters = 'mel'          female : male   =      6.5 : 1.0
#              last_letter = 'r'              male : female =      6.5 : 1.0
#          first_3_letters = 'wal'            male : female =      6.4 : 1.0
#          first_3_letters = 'her'            male : female =      6.4 : 1.0
#           last_2_letters = 'ig'             male : female =      6.3 : 1.0
#           last_2_letters = 'ew'             male : female =      6.3 : 1.0
#          first_3_letters = 'lor'          female : male   =      6.3 : 1.0
#           last_2_letters = 'ee'           female : male   =      6.3 : 1.0
#           last_3_letters = 'ssy'          female : male   =      6.2 : 1.0
#           last_2_letters = 'es'             male : female =      6.1 : 1.0
#           last_2_letters = 'ev'             male : female =      6.1 : 1.0
#           last_2_letters = 'go'             male : female =      6.1 : 1.0
#           last_2_letters = 'am'             male : female =      6.0 : 1.0
#           last_2_letters = 'di'           female : male   =      5.9 : 1.0
#           last_2_letters = 'ed'             male : female =      5.9 : 1.0
#           last_3_letters = 'sie'          female : male   =      5.8 : 1.0
#           last_3_letters = 'ree'          female : male   =      5.8 : 1.0
#           last_3_letters = 'sta'          female : male   =      5.8 : 1.0
#          first_3_letters = 'gen'          female : male   =      5.8 : 1.0
#          first_3_letters = 'jan'          female : male   =      5.8 : 1.0
#          first_3_letters = 'flo'          female : male   =      5.8 : 1.0
#          first_3_letters = 'hay'            male : female =      5.7 : 1.0
#          first_3_letters = 'whi'            male : female =      5.7 : 1.0
#           last_3_letters = 'and'            male : female =      5.7 : 1.0
#           last_3_letters = 'nan'            male : female =      5.7 : 1.0
#           last_3_letters = 'lem'            male : female =      5.7 : 1.0
#           last_3_letters = 'iff'            male : female =      5.7 : 1.0
#           last_2_letters = 'ud'             male : female =      5.7 : 1.0
#           last_3_letters = 'ron'            male : female =      5.6 : 1.0
#           last_3_letters = 'iah'            male : female =      5.6 : 1.0
#           last_3_letters = 'ddy'            male : female =      5.6 : 1.0
#           last_2_letters = 'sh'             male : female =      5.5 : 1.0
#          first_2_letters = 'ce'           female : male   =      5.4 : 1.0
#          first_3_letters = 'ric'            male : female =      5.4 : 1.0
#           last_3_letters = 'ika'          female : male   =      5.4 : 1.0
#           last_3_letters = 'ndi'          female : male   =      5.4 : 1.0
#           last_3_letters = 'dee'          female : male   =      5.4 : 1.0
#           last_3_letters = 'ryn'          female : male   =      5.4 : 1.0
#          first_3_letters = 'ama'          female : male   =      5.3 : 1.0
#          first_3_letters = 'ken'            male : female =      5.3 : 1.0
#          first_3_letters = 'alf'            male : female =      5.3 : 1.0
#           last_2_letters = 'ha'           female : male   =      5.3 : 1.0
#           last_3_letters = 'van'            male : female =      5.3 : 1.0
#              last_letter = 'w'              male : female =      5.1 : 1.0
#           last_3_letters = 'lyn'          female : male   =      5.1 : 1.0
#          first_2_letters = 'we'             male : female =      5.0 : 1.0
#           last_2_letters = 'oy'             male : female =      5.0 : 1.0
#           last_2_letters = 'ke'             male : female =      5.0 : 1.0
#           last_2_letters = 'ai'             male : female =      5.0 : 1.0
#           last_3_letters = 'nah'          female : male   =      4.9 : 1.0
#           last_3_letters = 'tti'          female : male   =      4.9 : 1.0
#          first_3_letters = 'myr'          female : male   =      4.9 : 1.0
#          first_3_letters = 'kor'          female : male   =      4.9 : 1.0
#          first_3_letters = 'hel'          female : male   =      4.9 : 1.0
#           last_3_letters = 'sha'          female : male   =      4.8 : 1.0
#           last_3_letters = 'ise'          female : male   =      4.8 : 1.0
#          first_2_letters = 'fa'           female : male   =      4.7 : 1.0
#             first_letter = 'w'              male : female =      4.7 : 1.0
#          first_3_letters = 'sco'            male : female =      4.7 : 1.0
#          first_3_letters = 'say'            male : female =      4.7 : 1.0
#          first_3_letters = 'fle'            male : female =      4.7 : 1.0
#          first_3_letters = 'rey'            male : female =      4.7 : 1.0
#          first_3_letters = 'teo'            male : female =      4.7 : 1.0
#           last_3_letters = 'ann'          female : male   =      4.7 : 1.0
#           last_3_letters = 'von'            male : female =      4.7 : 1.0
#           last_3_letters = 'sel'            male : female =      4.7 : 1.0
#           last_3_letters = 'ome'            male : female =      4.7 : 1.0
#           last_3_letters = 'uel'            male : female =      4.7 : 1.0
#           last_3_letters = 'ake'            male : female =      4.7 : 1.0
#           last_3_letters = 'ros'            male : female =      4.7 : 1.0
#           last_3_letters = 'hon'            male : female =      4.7 : 1.0
#           last_3_letters = 'ber'            male : female =      4.7 : 1.0
#           last_3_letters = 'den'            male : female =      4.7 : 1.0
#           last_3_letters = 'ott'            male : female =      4.7 : 1.0
#           last_3_letters = 'lah'          female : male   =      4.5 : 1.0
#          first_3_letters = 'est'          female : male   =      4.5 : 1.0
#          first_3_letters = 'bel'          female : male   =      4.5 : 1.0
#          first_2_letters = 'go'             male : female =      4.4 : 1.0
#          first_3_letters = 'qui'            male : female =      4.3 : 1.0
#          first_3_letters = 'tho'            male : female =      4.3 : 1.0
#           last_2_letters = 'nt'             male : female =      4.3 : 1.0
#           last_3_letters = 'ain'            male : female =      4.3 : 1.0
#           last_3_letters = 'ale'            male : female =      4.3 : 1.0
#           last_3_letters = 'her'            male : female =      4.3 : 1.0
#              last_letter = 's'              male : female =      4.3 : 1.0
#              last_letter = 'g'              male : female =      4.3 : 1.0
#          first_2_letters = 'ze'             male : female =      4.3 : 1.0
#           last_3_letters = 'han'            male : female =      4.2 : 1.0
#           last_3_letters = 'mon'            male : female =      4.2 : 1.0
#           last_2_letters = 'or'             male : female =      4.2 : 1.0
#           last_2_letters = 'si'           female : male   =      4.2 : 1.0
#           last_2_letters = 'nd'             male : female =      4.1 : 1.0
#           last_2_letters = 'ne'           female : male   =      4.1 : 1.0
#           last_3_letters = 'rie'          female : male   =      4.1 : 1.0
#          first_3_letters = 'mad'          female : male   =      4.1 : 1.0
#          first_2_letters = 'bu'             male : female =      4.1 : 1.0
#           last_2_letters = 'yn'           female : male   =      4.1 : 1.0
#           last_3_letters = 'ira'          female : male   =      4.1 : 1.0
#           last_3_letters = 'hea'          female : male   =      4.1 : 1.0
#          first_3_letters = 'for'            male : female =      4.1 : 1.0
#          first_3_letters = 'shi'          female : male   =      4.1 : 1.0
#          first_3_letters = 'sib'          female : male   =      4.1 : 1.0
#           last_3_letters = 'las'            male : female =      4.0 : 1.0
#           last_2_letters = 'ir'             male : female =      4.0 : 1.0
#          first_3_letters = 'bar'            male : female =      4.0 : 1.0
#           last_2_letters = 'ye'           female : male   =      4.0 : 1.0
#              last_letter = 'j'              male : female =      4.0 : 1.0
#          first_2_letters = 'ia'             male : female =      3.9 : 1.0
#           last_2_letters = 'nk'             male : female =      3.9 : 1.0
#           last_2_letters = 'ex'             male : female =      3.9 : 1.0
#              last_letter = 't'              male : female =      3.8 : 1.0
#           last_2_letters = 'ko'           female : male   =      3.8 : 1.0
#           last_3_letters = 'mar'            male : female =      3.8 : 1.0
#              last_letter = 'i'            female : male   =      3.7 : 1.0
#           last_2_letters = 'ad'             male : female =      3.7 : 1.0
#              last_letter = 'b'              male : female =      3.7 : 1.0
#           last_2_letters = 'sy'           female : male   =      3.7 : 1.0
#          first_3_letters = 'noa'            male : female =      3.6 : 1.0
#          first_3_letters = 'ral'            male : female =      3.6 : 1.0
#          first_3_letters = 'tre'            male : female =      3.6 : 1.0
#          first_3_letters = 'lam'            male : female =      3.6 : 1.0
#          first_3_letters = 'moi'            male : female =      3.6 : 1.0
#          first_3_letters = 'rem'            male : female =      3.6 : 1.0
#          first_3_letters = 'mos'            male : female =      3.6 : 1.0
#           last_3_letters = 'rly'          female : male   =      3.6 : 1.0
#           last_3_letters = 'ule'            male : female =      3.6 : 1.0
#           last_3_letters = 'itt'            male : female =      3.6 : 1.0
#           last_3_letters = 'hen'            male : female =      3.6 : 1.0
#           last_3_letters = 'kel'            male : female =      3.6 : 1.0
#           last_3_letters = 'aud'            male : female =      3.6 : 1.0
#           last_3_letters = 'jay'            male : female =      3.6 : 1.0
#           last_3_letters = 'meo'            male : female =      3.6 : 1.0
#           last_3_letters = 'ank'            male : female =      3.6 : 1.0
#           last_3_letters = 'nse'            male : female =      3.6 : 1.0
#           last_3_letters = 'oke'            male : female =      3.6 : 1.0
#           last_3_letters = 'nky'            male : female =      3.6 : 1.0
#           last_3_letters = 'iot'            male : female =      3.6 : 1.0
#           last_3_letters = 'rne'            male : female =      3.6 : 1.0
#           last_3_letters = 'gus'            male : female =      3.6 : 1.0
#           last_3_letters = 'lby'            male : female =      3.6 : 1.0
#          first_3_letters = 'kir'          female : male   =      3.6 : 1.0
#          first_3_letters = 'bob'          female : male   =      3.6 : 1.0
#          first_3_letters = 'kal'          female : male   =      3.6 : 1.0
#          first_3_letters = 'mai'          female : male   =      3.6 : 1.0
#          first_3_letters = 'edi'          female : male   =      3.6 : 1.0
#          first_2_letters = 'li'           female : male   =      3.6 : 1.0
#          first_3_letters = 'lyn'          female : male   =      3.6 : 1.0
#          first_2_letters = 'gl'           female : male   =      3.5 : 1.0
#           last_2_letters = 'ki'           female : male   =      3.5 : 1.0
#           last_3_letters = 'ani'          female : male   =      3.5 : 1.0
#          first_2_letters = 'za'             male : female =      3.5 : 1.0
#          first_3_letters = 'sim'            male : female =      3.4 : 1.0
#          first_3_letters = 'gio'            male : female =      3.4 : 1.0
#           last_3_letters = 'tan'            male : female =      3.4 : 1.0
#           last_3_letters = 'vis'            male : female =      3.4 : 1.0
#           last_3_letters = 'rge'            male : female =      3.4 : 1.0
#           last_3_letters = 'ger'            male : female =      3.4 : 1.0
#           last_3_letters = 'key'            male : female =      3.4 : 1.0
#           last_3_letters = 'inn'            male : female =      3.4 : 1.0
#           last_2_letters = 'za'           female : male   =      3.4 : 1.0
#           last_3_letters = 'ynn'          female : male   =      3.4 : 1.0
#           last_3_letters = 'nce'            male : female =      3.4 : 1.0
#          first_3_letters = 'jac'          female : male   =      3.3 : 1.0
#           last_2_letters = 'li'           female : male   =      3.3 : 1.0
#          first_3_letters = 'dav'            male : female =      3.3 : 1.0
#           last_2_letters = 'an'             male : female =      3.3 : 1.0
#          first_2_letters = 'ly'           female : male   =      3.3 : 1.0
#           last_2_letters = 'tt'             male : female =      3.3 : 1.0
#           last_2_letters = 'bi'           female : male   =      3.2 : 1.0
#              last_letter = 'u'              male : female =      3.2 : 1.0
#          first_2_letters = 'ba'             male : female =      3.2 : 1.0
#           last_3_letters = 'dis'          female : male   =      3.2 : 1.0
#           last_3_letters = 'sse'          female : male   =      3.2 : 1.0
#          first_3_letters = 'bri'          female : male   =      3.2 : 1.0
#          first_3_letters = 'ode'          female : male   =      3.2 : 1.0
#          first_3_letters = 'lee'          female : male   =      3.2 : 1.0
#          first_3_letters = 'kas'          female : male   =      3.2 : 1.0
#          first_3_letters = 'eth'          female : male   =      3.2 : 1.0
#          first_3_letters = 'eva'          female : male   =      3.2 : 1.0
#          first_3_letters = 'nel'          female : male   =      3.2 : 1.0
#          first_3_letters = 'far'          female : male   =      3.2 : 1.0
#          first_3_letters = 'tru'          female : male   =      3.2 : 1.0
#          first_3_letters = 'ore'          female : male   =      3.2 : 1.0
#           last_3_letters = 'lie'          female : male   =      3.2 : 1.0
#          first_3_letters = 'car'          female : male   =      3.2 : 1.0
#          first_2_letters = 'sc'             male : female =      3.1 : 1.0
#           last_2_letters = 'pe'             male : female =      3.1 : 1.0
#           last_2_letters = 'eo'             male : female =      3.1 : 1.0
#          first_2_letters = 'ca'           female : male   =      3.1 : 1.0
#          first_2_letters = 'th'             male : female =      3.1 : 1.0
#          first_3_letters = 'del'          female : male   =      3.0 : 1.0
#           last_2_letters = 'ae'           female : male   =      3.0 : 1.0
#           last_2_letters = 'ba'           female : male   =      3.0 : 1.0
#          first_2_letters = 'my'           female : male   =      3.0 : 1.0
#          first_2_letters = 'es'           female : male   =      3.0 : 1.0
#           last_3_letters = 'ile'          female : male   =      3.0 : 1.0
#           last_3_letters = 'ari'          female : male   =      3.0 : 1.0
#          first_3_letters = 'reg'            male : female =      2.9 : 1.0
#          first_3_letters = 'dev'          female : male   =      2.9 : 1.0
#          first_3_letters = 'cri'          female : male   =      2.9 : 1.0
#          first_3_letters = 'mag'          female : male   =      2.9 : 1.0
#           last_3_letters = 'ien'            male : female =      2.9 : 1.0
#           last_3_letters = 'ond'            male : female =      2.9 : 1.0
#           last_3_letters = 'yle'            male : female =      2.9 : 1.0
#           last_3_letters = 'dan'            male : female =      2.9 : 1.0
#           last_3_letters = 'ery'            male : female =      2.9 : 1.0
#          first_2_letters = 'na'           female : male   =      2.9 : 1.0
#          first_3_letters = 'ram'            male : female =      2.8 : 1.0
#          first_3_letters = 'gav'            male : female =      2.8 : 1.0
#          first_3_letters = 'ser'            male : female =      2.8 : 1.0
#          first_3_letters = 'fri'            male : female =      2.8 : 1.0
#          first_3_letters = 'alb'            male : female =      2.8 : 1.0
#           last_3_letters = 'are'            male : female =      2.8 : 1.0
#           last_3_letters = 'nte'            male : female =      2.8 : 1.0
#           last_3_letters = 'rby'            male : female =      2.8 : 1.0
#           last_3_letters = 'bbi'          female : male   =      2.8 : 1.0
#           last_3_letters = 'eri'          female : male   =      2.8 : 1.0
#          first_2_letters = 'aj'             male : female =      2.8 : 1.0
#           last_2_letters = 'ou'             male : female =      2.8 : 1.0
#           last_2_letters = 'bo'             male : female =      2.8 : 1.0
#           last_2_letters = 'we'             male : female =      2.8 : 1.0
#           last_2_letters = 'so'             male : female =      2.8 : 1.0
#           last_2_letters = 'ok'             male : female =      2.8 : 1.0
#           last_2_letters = 'pp'             male : female =      2.8 : 1.0
#          first_3_letters = 'til'          female : male   =      2.8 : 1.0
#          first_3_letters = 'cec'          female : male   =      2.8 : 1.0
#          first_3_letters = 'ara'          female : male   =      2.8 : 1.0
#          first_3_letters = 'ame'          female : male   =      2.8 : 1.0
#          first_3_letters = 'ely'          female : male   =      2.8 : 1.0
#          first_3_letters = 'kai'          female : male   =      2.8 : 1.0
#          first_3_letters = 'lia'          female : male   =      2.8 : 1.0
#          first_2_letters = 'et'           female : male   =      2.8 : 1.0
#          first_3_letters = 'wil'            male : female =      2.7 : 1.0
#          first_3_letters = 'jer'            male : female =      2.7 : 1.0
#          first_2_letters = 'ha'             male : female =      2.7 : 1.0
#             first_letter = 'q'              male : female =      2.7 : 1.0
#           last_2_letters = 'me'             male : female =      2.7 : 1.0
#          first_3_letters = 'kim'          female : male   =      2.7 : 1.0
#          first_3_letters = 'sar'          female : male   =      2.7 : 1.0
#           last_3_letters = 'eth'          female : male   =      2.7 : 1.0
#          first_2_letters = 'qu'             male : female =      2.7 : 1.0
#          first_2_letters = 'ag'           female : male   =      2.7 : 1.0
#          first_2_letters = 'ru'             male : female =      2.6 : 1.0
#          first_2_letters = 'me'           female : male   =      2.6 : 1.0
#          first_2_letters = 'wi'             male : female =      2.6 : 1.0
#           last_2_letters = 'in'             male : female =      2.6 : 1.0
#          first_3_letters = 'rup'            male : female =      2.6 : 1.0
#          first_3_letters = 'had'            male : female =      2.6 : 1.0
#          first_3_letters = 'die'            male : female =      2.6 : 1.0
#          first_3_letters = 'fer'            male : female =      2.6 : 1.0
#          first_3_letters = 'rav'            male : female =      2.6 : 1.0
#          first_3_letters = 'elm'            male : female =      2.6 : 1.0
#          first_3_letters = 'sig'            male : female =      2.6 : 1.0
#          first_3_letters = 'thi'            male : female =      2.6 : 1.0
#          first_3_letters = 'tob'            male : female =      2.6 : 1.0
#          first_3_letters = 'sul'            male : female =      2.6 : 1.0
#          first_3_letters = 'fin'            male : female =      2.6 : 1.0
#          first_3_letters = 'joh'            male : female =      2.6 : 1.0
#          first_3_letters = 'max'            male : female =      2.6 : 1.0
#          first_3_letters = 'zol'            male : female =      2.6 : 1.0
#          first_3_letters = 'pac'            male : female =      2.6 : 1.0
#          first_3_letters = 'alp'            male : female =      2.6 : 1.0
#          first_3_letters = 'mat'            male : female =      2.6 : 1.0
#          first_3_letters = 'aja'            male : female =      2.6 : 1.0
#          first_3_letters = 'fab'            male : female =      2.6 : 1.0
#          first_3_letters = 'ori'            male : female =      2.6 : 1.0
#          first_3_letters = 'ole'            male : female =      2.6 : 1.0
#          first_3_letters = 'kev'            male : female =      2.6 : 1.0
#          first_3_letters = 'gir'            male : female =      2.6 : 1.0
#          first_3_letters = 'ola'            male : female =      2.6 : 1.0
#          first_3_letters = 'iza'            male : female =      2.6 : 1.0
#          first_2_letters = 'ky'           female : male   =      2.6 : 1.0
#          first_2_letters = 'ye'           female : male   =      2.6 : 1.0
#           last_3_letters = 'kip'            male : female =      2.6 : 1.0
#           last_3_letters = 'tes'            male : female =      2.6 : 1.0
#           last_3_letters = 'fin'            male : female =      2.6 : 1.0
#           last_3_letters = 'elo'            male : female =      2.6 : 1.0
#           last_3_letters = 'ael'            male : female =      2.6 : 1.0
#           last_3_letters = 'sly'            male : female =      2.6 : 1.0
#           last_3_letters = 'she'            male : female =      2.6 : 1.0
#           last_3_letters = 'rdy'            male : female =      2.6 : 1.0
#           last_3_letters = 'ern'            male : female =      2.6 : 1.0
#           last_3_letters = 'ady'            male : female =      2.6 : 1.0
#           last_3_letters = 'ens'            male : female =      2.6 : 1.0
#           last_3_letters = 'ook'            male : female =      2.6 : 1.0
#           last_3_letters = 'uce'            male : female =      2.6 : 1.0
#           last_3_letters = 'ass'            male : female =      2.6 : 1.0
#           last_3_letters = 'vor'            male : female =      2.6 : 1.0
#           last_3_letters = 'zzy'            male : female =      2.6 : 1.0
#           last_3_letters = 'had'            male : female =      2.6 : 1.0
#           last_3_letters = 'lix'            male : female =      2.6 : 1.0
#           last_3_letters = 'eas'            male : female =      2.6 : 1.0
#           last_3_letters = 'red'            male : female =      2.6 : 1.0
#           last_3_letters = 'che'            male : female =      2.6 : 1.0
#           last_3_letters = 'gil'            male : female =      2.6 : 1.0
#           last_3_letters = 'cal'            male : female =      2.6 : 1.0
#           last_3_letters = 'och'            male : female =      2.6 : 1.0
#           last_3_letters = 'ird'            male : female =      2.6 : 1.0
#           last_3_letters = 'dal'            male : female =      2.6 : 1.0
#           last_3_letters = 'lex'            male : female =      2.6 : 1.0
#           last_3_letters = 'lou'            male : female =      2.6 : 1.0
#           last_3_letters = 'rio'            male : female =      2.6 : 1.0
#           last_3_letters = 'ipp'            male : female =      2.6 : 1.0
#           last_3_letters = 'mel'            male : female =      2.6 : 1.0
#           last_3_letters = 'gel'            male : female =      2.6 : 1.0
#           last_3_letters = 'res'            male : female =      2.6 : 1.0
#          first_2_letters = 'ur'             male : female =      2.6 : 1.0
#             first_letter = 'u'              male : female =      2.6 : 1.0
#           last_3_letters = 'rey'            male : female =      2.5 : 1.0
#          first_3_letters = 'cor'          female : male   =      2.5 : 1.0
#           last_3_letters = 'ele'          female : male   =      2.5 : 1.0
#           last_3_letters = 'ian'            male : female =      2.5 : 1.0
#          first_3_letters = 'cam'          female : male   =      2.5 : 1.0
#          first_2_letters = 'lo'           female : male   =      2.5 : 1.0
#          first_3_letters = 'ado'            male : female =      2.5 : 1.0
#          first_3_letters = 'hor'            male : female =      2.5 : 1.0
#           last_3_letters = 'ail'            male : female =      2.4 : 1.0
#           last_3_letters = 'air'            male : female =      2.4 : 1.0
#           last_3_letters = 'igh'            male : female =      2.4 : 1.0
#           last_3_letters = 'ier'            male : female =      2.4 : 1.0
#          first_2_letters = 'su'           female : male   =      2.4 : 1.0
#          first_3_letters = 'van'          female : male   =      2.4 : 1.0
#          first_3_letters = 'tri'          female : male   =      2.4 : 1.0
#          first_3_letters = 'ker'          female : male   =      2.4 : 1.0
#          first_3_letters = 'sel'          female : male   =      2.4 : 1.0
#          first_3_letters = 'tor'            male : female =      2.4 : 1.0
#          first_2_letters = 'to'             male : female =      2.4 : 1.0
#           last_2_letters = 'oe'             male : female =      2.4 : 1.0
#           last_3_letters = 'ace'            male : female =      2.4 : 1.0
#             first_letter = 'k'            female : male   =      2.4 : 1.0
#          first_3_letters = 'sal'            male : female =      2.4 : 1.0
#          first_3_letters = 'mor'            male : female =      2.4 : 1.0
#          first_2_letters = 'hi'             male : female =      2.4 : 1.0
#          first_2_letters = 'ga'             male : female =      2.4 : 1.0
#           last_3_letters = 'xie'          female : male   =      2.4 : 1.0
#           last_3_letters = 'nee'          female : male   =      2.4 : 1.0
#           last_3_letters = 'dre'          female : male   =      2.4 : 1.0
#           last_3_letters = 'ely'          female : male   =      2.4 : 1.0
#           last_3_letters = 'ide'          female : male   =      2.4 : 1.0
#           last_3_letters = 'rea'          female : male   =      2.4 : 1.0
#          first_3_letters = 'lot'          female : male   =      2.3 : 1.0
#          first_3_letters = 'urs'          female : male   =      2.3 : 1.0
#          first_3_letters = 'job'          female : male   =      2.3 : 1.0
#          first_3_letters = 'mea'          female : male   =      2.3 : 1.0
#          first_3_letters = 'mis'          female : male   =      2.3 : 1.0
#          first_2_letters = 'dr'             male : female =      2.3 : 1.0
#          first_2_letters = 'iz'             male : female =      2.3 : 1.0
#           last_2_letters = 'ur'             male : female =      2.3 : 1.0
#           last_2_letters = 'ab'             male : female =      2.3 : 1.0
#           last_2_letters = 'eg'             male : female =      2.3 : 1.0
#          first_3_letters = 'ben'            male : female =      2.3 : 1.0
#          first_2_letters = 'ul'             male : female =      2.3 : 1.0
#           last_2_letters = 'ot'             male : female =      2.3 : 1.0
#          first_3_letters = 'val'          female : male   =      2.3 : 1.0
#           last_2_letters = 'se'           female : male   =      2.2 : 1.0
#          first_3_letters = 'cas'          female : male   =      2.2 : 1.0
#          first_3_letters = 'ali'          female : male   =      2.2 : 1.0
#           last_2_letters = 'jo'           female : male   =      2.2 : 1.0
#             first_letter = 'h'              male : female =      2.2 : 1.0
#           last_2_letters = 'll'             male : female =      2.2 : 1.0
#          first_2_letters = 'bl'           female : male   =      2.2 : 1.0
#          first_2_letters = 'am'           female : male   =      2.2 : 1.0
#          first_3_letters = 'elw'            male : female =      2.2 : 1.0
#          first_3_letters = 'pep'            male : female =      2.2 : 1.0
#          first_3_letters = 'gun'            male : female =      2.2 : 1.0
#          first_3_letters = 'mit'            male : female =      2.2 : 1.0
#          first_3_letters = 'rom'            male : female =      2.2 : 1.0
#          first_3_letters = 'mah'            male : female =      2.2 : 1.0
#          first_2_letters = 'pi'             male : female =      2.2 : 1.0
#           last_2_letters = 'de'           female : male   =      2.2 : 1.0
#           last_3_letters = 'ent'            male : female =      2.2 : 1.0
#           last_3_letters = 'eil'            male : female =      2.2 : 1.0
#           last_3_letters = 'hal'            male : female =      2.2 : 1.0
#           last_3_letters = 'rny'            male : female =      2.2 : 1.0
#           last_3_letters = 'ray'            male : female =      2.2 : 1.0
#           last_3_letters = 'ate'            male : female =      2.2 : 1.0
#           last_3_letters = 'bin'            male : female =      2.2 : 1.0
#          first_3_letters = 'gin'          female : male   =      2.2 : 1.0
#          first_3_letters = 'pau'          female : male   =      2.2 : 1.0
#          first_3_letters = 'lau'          female : male   =      2.2 : 1.0
#          first_3_letters = 'mer'          female : male   =      2.1 : 1.0
#          first_2_letters = 'du'             male : female =      2.1 : 1.0
#              last_letter = 'n'              male : female =      2.1 : 1.0
#          first_3_letters = 'mar'          female : male   =      2.1 : 1.0
#           last_2_letters = 'ow'             male : female =      2.1 : 1.0
#           last_3_letters = 'rri'          female : male   =      2.1 : 1.0
#           last_3_letters = 'tin'            male : female =      2.1 : 1.0
#          first_3_letters = 'adr'          female : male   =      2.1 : 1.0
#          first_3_letters = 'tam'          female : male   =      2.1 : 1.0
#             first_letter = 'x'              male : female =      2.1 : 1.0
#          first_2_letters = 'mu'             male : female =      2.1 : 1.0
#          first_2_letters = 'ko'           female : male   =      2.1 : 1.0
#           last_3_letters = 'ndy'          female : male   =      2.0 : 1.0
#          first_3_letters = 'han'            male : female =      2.0 : 1.0
#          first_3_letters = 'san'            male : female =      2.0 : 1.0
#          first_2_letters = 'dy'           female : male   =      2.0 : 1.0
#           last_2_letters = 'at'             male : female =      2.0 : 1.0
#           last_2_letters = 'ue'             male : female =      2.0 : 1.0
#           last_3_letters = 'ley'            male : female =      2.0 : 1.0
#          first_3_letters = 'sha'          female : male   =      2.0 : 1.0
#          first_3_letters = 'sta'            male : female =      2.0 : 1.0
#          first_3_letters = 'gri'            male : female =      2.0 : 1.0
#          first_3_letters = 'sid'            male : female =      2.0 : 1.0
#          first_3_letters = 'pie'            male : female =      2.0 : 1.0
#          first_3_letters = 'fil'            male : female =      2.0 : 1.0
#          first_3_letters = 'rei'            male : female =      2.0 : 1.0
#          first_3_letters = 'ave'            male : female =      2.0 : 1.0
#          first_2_letters = 'ki'           female : male   =      2.0 : 1.0
#           last_3_letters = 'hel'            male : female =      2.0 : 1.0
#           last_3_letters = 'que'            male : female =      2.0 : 1.0
#           last_3_letters = 'rty'            male : female =      2.0 : 1.0
#          first_2_letters = 'ab'             male : female =      2.0 : 1.0
#           last_2_letters = 'ky'             male : female =      2.0 : 1.0
#          first_2_letters = 've'           female : male   =      2.0 : 1.0
#          first_2_letters = 'wy'             male : female =      2.0 : 1.0
#           last_3_letters = 'ill'            male : female =      2.0 : 1.0
#          first_2_letters = 'ja'           female : male   =      2.0 : 1.0
#          first_2_letters = 'ri'             male : female =      2.0 : 1.0
#           last_3_letters = 'udi'          female : male   =      1.9 : 1.0
#           last_3_letters = 'rid'          female : male   =      1.9 : 1.0
#           last_3_letters = 'odi'          female : male   =      1.9 : 1.0
#           last_3_letters = 'rit'          female : male   =      1.9 : 1.0
#           last_3_letters = 'ind'          female : male   =      1.9 : 1.0
#           last_3_letters = 'yce'          female : male   =      1.9 : 1.0
#           last_3_letters = 'acy'          female : male   =      1.9 : 1.0
#           last_3_letters = 'iss'          female : male   =      1.9 : 1.0
#           last_3_letters = 'oni'          female : male   =      1.9 : 1.0
#           last_3_letters = 'net'          female : male   =      1.9 : 1.0
#           last_3_letters = 'ean'          female : male   =      1.9 : 1.0
#           last_3_letters = 'tty'          female : male   =      1.9 : 1.0
#           last_3_letters = 'ese'          female : male   =      1.9 : 1.0
#           last_2_letters = 'hy'             male : female =      1.9 : 1.0
#          first_3_letters = 'joe'          female : male   =      1.9 : 1.0
#          first_3_letters = 'wan'          female : male   =      1.9 : 1.0
#          first_3_letters = 'pea'          female : male   =      1.9 : 1.0
#          first_3_letters = 'eme'          female : male   =      1.9 : 1.0
#          first_3_letters = 'gly'          female : male   =      1.9 : 1.0
#          first_3_letters = 'ner'          female : male   =      1.9 : 1.0
#          first_3_letters = 'esm'          female : male   =      1.9 : 1.0
#          first_3_letters = 'lar'          female : male   =      1.9 : 1.0
#          first_3_letters = 'kam'          female : male   =      1.9 : 1.0
#          first_3_letters = 'chi'          female : male   =      1.9 : 1.0
#          first_3_letters = 'zor'          female : male   =      1.9 : 1.0
#          first_3_letters = 'aga'          female : male   =      1.9 : 1.0
#          first_3_letters = 'lel'          female : male   =      1.9 : 1.0
#          first_3_letters = 'gle'          female : male   =      1.9 : 1.0
#          first_3_letters = 'kip'          female : male   =      1.9 : 1.0
#          first_3_letters = 'rut'          female : male   =      1.9 : 1.0
#          first_3_letters = 'tat'          female : male   =      1.9 : 1.0
#          first_3_letters = 'kyl'          female : male   =      1.9 : 1.0
#          first_3_letters = 'bec'          female : male   =      1.9 : 1.0
#          first_3_letters = 'kit'          female : male   =      1.9 : 1.0
#          first_3_letters = 'gui'          female : male   =      1.9 : 1.0
#          first_3_letters = 'ver'          female : male   =      1.9 : 1.0
#          first_3_letters = 'que'          female : male   =      1.9 : 1.0
#          first_2_letters = 'st'             male : female =      1.9 : 1.0
#           last_2_letters = 'ay'             male : female =      1.9 : 1.0
#          first_2_letters = 'au'           female : male   =      1.9 : 1.0
#          first_3_letters = 'ern'            male : female =      1.9 : 1.0
#          first_2_letters = 'ev'           female : male   =      1.9 : 1.0
#          first_2_letters = 'kr'           female : male   =      1.9 : 1.0
#          first_2_letters = 'do'           female : male   =      1.9 : 1.0
#          first_2_letters = 'an'           female : male   =      1.9 : 1.0
#           last_2_letters = 'id'             male : female =      1.9 : 1.0
#           last_2_letters = 'nn'           female : male   =      1.9 : 1.0
#           last_2_letters = 'le'           female : male   =      1.9 : 1.0
#          first_2_letters = 'gr'             male : female =      1.9 : 1.0
#           last_3_letters = 'tie'          female : male   =      1.9 : 1.0
#           last_2_letters = 'ri'           female : male   =      1.8 : 1.0
#           last_3_letters = 'ten'            male : female =      1.8 : 1.0
#           last_2_letters = 'il'             male : female =      1.8 : 1.0
#              last_letter = 'e'            female : male   =      1.8 : 1.0
#             first_letter = 'z'              male : female =      1.8 : 1.0
#           last_3_letters = 'sey'          female : male   =      1.8 : 1.0
#           last_3_letters = 'nie'          female : male   =      1.8 : 1.0
#          first_3_letters = 'tom'            male : female =      1.8 : 1.0
#          first_3_letters = 'sil'            male : female =      1.8 : 1.0
#          first_3_letters = 'sam'            male : female =      1.8 : 1.0
#          first_3_letters = 'jud'            male : female =      1.8 : 1.0
#           last_2_letters = 'rg'           female : male   =      1.8 : 1.0
#          first_2_letters = 'ap'           female : male   =      1.8 : 1.0
#          first_2_letters = 'zi'           female : male   =      1.8 : 1.0
#                    has_U = True             male : female =      1.8 : 1.0
#           last_3_letters = 'ryl'          female : male   =      1.8 : 1.0
#          first_3_letters = 'kri'          female : male   =      1.8 : 1.0
#          first_3_letters = 'ang'          female : male   =      1.8 : 1.0
#          first_3_letters = 'ana'          female : male   =      1.8 : 1.0
#          first_3_letters = 'har'            male : female =      1.8 : 1.0
#          first_2_letters = 'el'           female : male   =      1.8 : 1.0
#              last_letter = 'l'              male : female =      1.8 : 1.0
#           last_2_letters = 'by'             male : female =      1.8 : 1.0
#          first_3_letters = 'dan'          female : male   =      1.8 : 1.0
#          first_3_letters = 'nor'            male : female =      1.8 : 1.0
#          first_3_letters = 'bra'            male : female =      1.8 : 1.0
#          first_3_letters = 'hen'            male : female =      1.8 : 1.0
#           last_3_letters = 'ett'            male : female =      1.8 : 1.0
#          first_2_letters = 'ra'             male : female =      1.8 : 1.0
#           last_2_letters = 'al'             male : female =      1.7 : 1.0
#          first_3_letters = 'fel'          female : male   =      1.7 : 1.0
#          first_3_letters = 'joa'          female : male   =      1.7 : 1.0
#          first_2_letters = 'mo'             male : female =      1.7 : 1.0
#           last_2_letters = 'ie'           female : male   =      1.7 : 1.0
#          first_3_letters = 'pat'            male : female =      1.7 : 1.0
#          first_3_letters = 'eli'          female : male   =      1.7 : 1.0
#          first_2_letters = 're'             male : female =      1.7 : 1.0
#          first_2_letters = 'ma'           female : male   =      1.7 : 1.0
#             first_letter = 'l'            female : male   =      1.7 : 1.0
#          first_2_letters = 'sa'             male : female =      1.7 : 1.0
#          first_3_letters = 'and'            male : female =      1.7 : 1.0
#              last_letter = 'x'              male : female =      1.7 : 1.0
#          first_3_letters = 'jul'          female : male   =      1.7 : 1.0
#          first_2_letters = 'cr'           female : male   =      1.7 : 1.0
#           last_3_letters = 'ude'          female : male   =      1.7 : 1.0
#           last_3_letters = 'ire'          female : male   =      1.7 : 1.0
#           last_3_letters = 'fer'          female : male   =      1.7 : 1.0
#           last_3_letters = 'cha'          female : male   =      1.7 : 1.0
#          first_2_letters = 'ik'             male : female =      1.7 : 1.0
#          first_2_letters = 'xe'             male : female =      1.7 : 1.0
#          first_2_letters = 'en'             male : female =      1.7 : 1.0
#          first_2_letters = 'ot'             male : female =      1.7 : 1.0
#          first_2_letters = 'xy'             male : female =      1.7 : 1.0
#          first_2_letters = 'oc'             male : female =      1.7 : 1.0
#          first_2_letters = 'fu'             male : female =      1.7 : 1.0
#          first_2_letters = 'ho'             male : female =      1.7 : 1.0
#          first_2_letters = 'um'             male : female =      1.7 : 1.0
#          first_2_letters = 'ir'             male : female =      1.7 : 1.0
#          first_2_letters = 'ib'             male : female =      1.7 : 1.0
#          first_2_letters = 'ay'             male : female =      1.7 : 1.0
#           last_2_letters = 'fy'             male : female =      1.7 : 1.0
#           last_2_letters = 'vy'             male : female =      1.7 : 1.0
#           last_2_letters = 'ag'             male : female =      1.7 : 1.0
#           last_2_letters = 'oh'             male : female =      1.7 : 1.0
#           last_2_letters = 'au'             male : female =      1.7 : 1.0
#           last_2_letters = 'lu'             male : female =      1.7 : 1.0
#           last_2_letters = 'rr'             male : female =      1.7 : 1.0
#           last_2_letters = 'zy'             male : female =      1.7 : 1.0
#           last_2_letters = 'ji'             male : female =      1.7 : 1.0
#           last_2_letters = 've'             male : female =      1.7 : 1.0
#           last_2_letters = 'ei'             male : female =      1.7 : 1.0
#           last_2_letters = 'rl'             male : female =      1.7 : 1.0
#           last_2_letters = 'jy'             male : female =      1.7 : 1.0
# ...
#             first_letter = 'b'              male : female =      1.2 : 1.0
#          first_3_letters = 'ell'          female : male   =      1.2 : 1.0
#          first_3_letters = 'emm'          female : male   =      1.2 : 1.0
#          first_3_letters = 'gab'          female : male   =      1.2 : 1.0
#                    has_s = True             male : female =      1.2 : 1.0
#          first_3_letters = 'ada'            male : female =      1.2 : 1.0
#          first_3_letters = 'may'            male : female =      1.2 : 1.0
#          first_3_letters = 'dio'            male : female =      1.2 : 1.0
#          first_3_letters = 'tar'            male : female =      1.2 : 1.0
#          first_3_letters = 'wyn'            male : female =      1.2 : 1.0
#          first_3_letters = 'jod'            male : female =      1.2 : 1.0
#          first_3_letters = 'amb'            male : female =      1.2 : 1.0
#          first_3_letters = 'tal'            male : female =      1.2 : 1.0
#           last_3_letters = 'die'          female : male   =      1.2 : 1.0
#           last_3_letters = 'vie'          female : male   =      1.2 : 1.0
#           last_3_letters = 'del'          female : male   =      1.2 : 1.0
#           last_3_letters = 'non'          female : male   =      1.2 : 1.0
#           last_3_letters = 'one'            male : female =      1.2 : 1.0
#           last_3_letters = 'ffy'            male : female =      1.2 : 1.0
#          first_3_letters = 'den'          female : male   =      1.2 : 1.0
#           last_2_letters = 'ny'             male : female =      1.2 : 1.0
#          first_3_letters = 'ing'            male : female =      1.2 : 1.0
#           last_3_letters = 'thy'          female : male   =      1.2 : 1.0
#          first_2_letters = 'vo'             male : female =      1.2 : 1.0
#          first_2_letters = 'kl'             male : female =      1.2 : 1.0
#          first_2_letters = 'or'             male : female =      1.2 : 1.0
#           last_3_letters = 'cky'            male : female =      1.2 : 1.0
#           last_3_letters = 'ary'            male : female =      1.2 : 1.0
#          first_3_letters = 'les'          female : male   =      1.2 : 1.0
#          first_2_letters = 'ge'           female : male   =      1.2 : 1.0
#                    has_O = False          female : male   =      1.2 : 1.0
#           last_2_letters = 'th'           female : male   =      1.2 : 1.0
#                    has_r = True             male : female =      1.2 : 1.0
#                    has_E = False            male : female =      1.2 : 1.0
#          first_2_letters = 'no'             male : female =      1.2 : 1.0
#             first_letter = 'j'            female : male   =      1.2 : 1.0
#           last_3_letters = 'len'          female : male   =      1.2 : 1.0
#                    has_l = False            male : female =      1.2 : 1.0
#                    has_n = True           female : male   =      1.2 : 1.0
#           last_3_letters = 'udy'          female : male   =      1.2 : 1.0
#           last_3_letters = 'rel'          female : male   =      1.2 : 1.0
#           last_3_letters = 'ere'          female : male   =      1.2 : 1.0
#           last_3_letters = 'kki'          female : male   =      1.2 : 1.0
#           last_3_letters = 'ggy'          female : male   =      1.2 : 1.0
#           last_3_letters = 'ppy'          female : male   =      1.2 : 1.0
#          first_2_letters = 'ni'             male : female =      1.2 : 1.0
#          first_2_letters = 'cl'             male : female =      1.2 : 1.0
#          first_3_letters = 'jea'            male : female =      1.2 : 1.0
#          first_3_letters = 'zar'          female : male   =      1.2 : 1.0
#          first_3_letters = 'hei'          female : male   =      1.2 : 1.0
#          first_3_letters = 'oth'          female : male   =      1.2 : 1.0
#          first_3_letters = 'enr'          female : male   =      1.2 : 1.0
#          first_3_letters = 'noe'          female : male   =      1.2 : 1.0
#          first_3_letters = 'nol'          female : male   =      1.2 : 1.0
#          first_3_letters = 'ton'          female : male   =      1.2 : 1.0
#          first_3_letters = 'raf'          female : male   =      1.2 : 1.0
#          first_3_letters = 'lou'          female : male   =      1.2 : 1.0
#          first_3_letters = 'vic'          female : male   =      1.2 : 1.0
#          first_3_letters = 'bil'          female : male   =      1.2 : 1.0
#          first_3_letters = 'don'          female : male   =      1.2 : 1.0
#          first_2_letters = 'di'             male : female =      1.2 : 1.0
#          first_3_letters = 'ash'            male : female =      1.1 : 1.0
#          first_3_letters = 'tab'            male : female =      1.1 : 1.0
#          first_3_letters = 'eri'            male : female =      1.1 : 1.0
#          first_2_letters = 'as'           female : male   =      1.1 : 1.0
#                    has_r = False          female : male   =      1.1 : 1.0
#          first_2_letters = 'bo'             male : female =      1.1 : 1.0
#           last_3_letters = 'rry'          female : male   =      1.1 : 1.0
#          first_2_letters = 'is'             male : female =      1.1 : 1.0
#          first_2_letters = 'eu'           female : male   =      1.1 : 1.0
#           last_3_letters = 'lin'          female : male   =      1.1 : 1.0
#          first_3_letters = 'fra'          female : male   =      1.1 : 1.0
#          first_2_letters = 'gu'             male : female =      1.1 : 1.0
#          first_3_letters = 'ger'          female : male   =      1.1 : 1.0
#                    has_E = True           female : male   =      1.1 : 1.0
#             first_letter = 'n'            female : male   =      1.1 : 1.0
#           last_3_letters = 'ris'          female : male   =      1.1 : 1.0
#          first_3_letters = 'eug'            male : female =      1.1 : 1.0
#          first_3_letters = 'jos'            male : female =      1.1 : 1.0
#          first_3_letters = 'man'            male : female =      1.1 : 1.0
#          first_3_letters = 'sas'            male : female =      1.1 : 1.0
#          first_3_letters = 'syd'            male : female =      1.1 : 1.0
#          first_3_letters = 'alo'            male : female =      1.1 : 1.0
#          first_3_letters = 'jus'            male : female =      1.1 : 1.0
#          first_3_letters = 'tie'            male : female =      1.1 : 1.0
#          first_3_letters = 'edd'            male : female =      1.1 : 1.0
#          first_3_letters = 'sho'            male : female =      1.1 : 1.0
#          first_3_letters = 'lay'            male : female =      1.1 : 1.0
#          first_3_letters = 'aus'            male : female =      1.1 : 1.0
#          first_3_letters = 'elv'            male : female =      1.1 : 1.0
#          first_3_letters = 'jas'            male : female =      1.1 : 1.0
#          first_3_letters = 'bru'            male : female =      1.1 : 1.0
#          first_2_letters = 'hy'           female : male   =      1.1 : 1.0
#           last_3_letters = 'ess'            male : female =      1.1 : 1.0
#           last_3_letters = 'zie'            male : female =      1.1 : 1.0
#           last_3_letters = 'ran'            male : female =      1.1 : 1.0
#           last_3_letters = 'ish'            male : female =      1.1 : 1.0
#           last_3_letters = 'rde'            male : female =      1.1 : 1.0
#           last_3_letters = 'tel'            male : female =      1.1 : 1.0
#           last_3_letters = 'ili'            male : female =      1.1 : 1.0
#           last_3_letters = 'yan'            male : female =      1.1 : 1.0
#           last_3_letters = 'rcy'            male : female =      1.1 : 1.0
#           last_3_letters = 'ith'          female : male   =      1.1 : 1.0
#                    has_n = False            male : female =      1.1 : 1.0
#          first_3_letters = 'cla'          female : male   =      1.1 : 1.0
#          first_3_letters = 'cal'          female : male   =      1.1 : 1.0
#          first_3_letters = 'lan'          female : male   =      1.1 : 1.0
#          first_2_letters = 'ke'             male : female =      1.1 : 1.0
#          first_2_letters = 'ol'           female : male   =      1.1 : 1.0
#                    has_t = True             male : female =      1.1 : 1.0
#          first_3_letters = 'cha'            male : female =      1.1 : 1.0
#          first_2_letters = 'ar'           female : male   =      1.1 : 1.0
#          first_2_letters = 'fi'             male : female =      1.1 : 1.0
#          first_2_letters = 'br'             male : female =      1.1 : 1.0
#          first_2_letters = 'le'           female : male   =      1.1 : 1.0
#          first_3_letters = 'pen'            male : female =      1.1 : 1.0
#          first_3_letters = 'bla'            male : female =      1.1 : 1.0
#          first_3_letters = 'bry'            male : female =      1.1 : 1.0
#          first_3_letters = 'rub'            male : female =      1.1 : 1.0
#           last_2_letters = 'py'           female : male   =      1.1 : 1.0
#           last_2_letters = 'vi'           female : male   =      1.1 : 1.0
#           last_2_letters = 'ix'           female : male   =      1.1 : 1.0
#          first_2_letters = 'ta'             male : female =      1.1 : 1.0
#                    has_U = False          female : male   =      1.1 : 1.0
#          first_2_letters = 'te'             male : female =      1.1 : 1.0
#           last_3_letters = 'nel'          female : male   =      1.1 : 1.0
#           last_3_letters = 'ial'          female : male   =      1.1 : 1.0
#           last_3_letters = 'aro'          female : male   =      1.1 : 1.0
#           last_3_letters = 'wen'          female : male   =      1.1 : 1.0
#           last_3_letters = 'osi'          female : male   =      1.1 : 1.0
#           last_3_letters = 'aun'          female : male   =      1.1 : 1.0
#           last_3_letters = 'eau'          female : male   =      1.1 : 1.0
#           last_3_letters = 'uli'          female : male   =      1.1 : 1.0
#           last_3_letters = 'ali'          female : male   =      1.1 : 1.0
#           last_3_letters = 'tsy'          female : male   =      1.1 : 1.0
#           last_3_letters = 'edy'          female : male   =      1.1 : 1.0
#           last_3_letters = 'ime'          female : male   =      1.1 : 1.0
#           last_3_letters = 'oly'          female : male   =      1.1 : 1.0
#           last_3_letters = 'oby'          female : male   =      1.1 : 1.0
#           last_3_letters = 'org'          female : male   =      1.1 : 1.0
#           last_3_letters = 'iet'          female : male   =      1.1 : 1.0
#           last_3_letters = 'ece'          female : male   =      1.1 : 1.0
#           last_3_letters = 'pie'          female : male   =      1.1 : 1.0
#           last_3_letters = 'sun'          female : male   =      1.1 : 1.0
#           last_3_letters = 'ble'          female : male   =      1.1 : 1.0
#             first_letter = 'i'            female : male   =      1.1 : 1.0
#          first_3_letters = 'ren'            male : female =      1.1 : 1.0
#          first_3_letters = 'bre'            male : female =      1.1 : 1.0
#          first_2_letters = 'al'             male : female =      1.1 : 1.0
#                    has_Y = True           female : male   =      1.1 : 1.0
#          first_3_letters = 'tyb'          female : male   =      1.1 : 1.0
#          first_3_letters = 'xen'          female : male   =      1.1 : 1.0
#          first_3_letters = 'dre'          female : male   =      1.1 : 1.0
#          first_3_letters = 'vil'          female : male   =      1.1 : 1.0
#          first_3_letters = 'hai'          female : male   =      1.1 : 1.0
#          first_3_letters = 'per'          female : male   =      1.1 : 1.0
#          first_3_letters = 'ivo'          female : male   =      1.1 : 1.0
#          first_3_letters = 'joc'          female : male   =      1.1 : 1.0
#          first_3_letters = 'avi'          female : male   =      1.1 : 1.0
#          first_3_letters = 'rah'          female : male   =      1.1 : 1.0
#          first_3_letters = 'eln'          female : male   =      1.1 : 1.0
#          first_3_letters = 'cai'          female : male   =      1.1 : 1.0
#          first_3_letters = 'fed'          female : male   =      1.1 : 1.0
#          first_3_letters = 'sun'          female : male   =      1.1 : 1.0
#          first_3_letters = 'jai'          female : male   =      1.1 : 1.0
#          first_3_letters = 'ari'          female : male   =      1.1 : 1.0
#          first_3_letters = 'cou'          female : male   =      1.1 : 1.0
#          first_3_letters = 'aub'          female : male   =      1.1 : 1.0
#          first_3_letters = 'daw'          female : male   =      1.1 : 1.0
#          first_3_letters = 'sca'          female : male   =      1.1 : 1.0
#          first_3_letters = 'nat'          female : male   =      1.1 : 1.0
#          first_3_letters = 'ale'          female : male   =      1.1 : 1.0
#          first_3_letters = 'cle'            male : female =      1.1 : 1.0
#                    has_s = False          female : male   =      1.1 : 1.0
#          first_2_letters = 'ne'             male : female =      1.1 : 1.0
#          first_2_letters = 'pe'             male : female =      1.1 : 1.0
#           last_2_letters = 'en'             male : female =      1.1 : 1.0
#          first_2_letters = 'ju'           female : male   =      1.0 : 1.0
#           last_3_letters = 'lis'          female : male   =      1.0 : 1.0
#          first_2_letters = 'fe'             male : female =      1.0 : 1.0
#          first_3_letters = 'chr'          female : male   =      1.0 : 1.0
#          first_3_letters = 'dar'          female : male   =      1.0 : 1.0
#          first_3_letters = 'isa'          female : male   =      1.0 : 1.0
#          first_2_letters = 'cy'             male : female =      1.0 : 1.0
#                    has_t = False          female : male   =      1.0 : 1.0
#          first_2_letters = 'ed'           female : male   =      1.0 : 1.0
#          first_2_letters = 'ro'           female : male   =      1.0 : 1.0
#           last_2_letters = 're'             male : female =      1.0 : 1.0
#          first_2_letters = 'va'             male : female =      1.0 : 1.0
#          first_3_letters = 'leo'            male : female =      1.0 : 1.0
#          first_3_letters = 'the'            male : female =      1.0 : 1.0
#          first_2_letters = 'so'           female : male   =      1.0 : 1.0
#           last_2_letters = 'et'             male : female =      1.0 : 1.0
#                    has_Y = False            male : female =      1.0 : 1.0
#             first_letter = 'f'            female : male   =      1.0 : 1.0
#          first_3_letters = 'tan'            male : female =      1.0 : 1.0
#          first_3_letters = 'gus'            male : female =      1.0 : 1.0
#          first_3_letters = 'ron'            male : female =      1.0 : 1.0
#          first_3_letters = 'jor'            male : female =      1.0 : 1.0
#           last_3_letters = 'nor'          female : male   =      1.0 : 1.0
#           last_3_letters = 'ily'          female : male   =      1.0 : 1.0
#           last_3_letters = 'ren'            male : female =      1.0 : 1.0
#          first_3_letters = 'eve'          female : male   =      1.0 : 1.0
#          first_3_letters = 'emi'          female : male   =      1.0 : 1.0
#          first_3_letters = 'lon'          female : male   =      1.0 : 1.0
#          first_3_letters = 'ora'          female : male   =      1.0 : 1.0
#          first_3_letters = 'she'            male : female =      1.0 : 1.0
#          first_2_letters = 'ch'             male : female =      1.0 : 1.0
#          first_2_letters = 'wr'             male : female =      1.0 : 1.0
#          first_2_letters = 'ry'             male : female =      1.0 : 1.0
#          first_2_letters = 'yv'             male : female =      1.0 : 1.0
#           last_2_letters = 'cy'           female : male   =      1.0 : 1.0
#           last_2_letters = 'rb'           female : male   =      1.0 : 1.0

# %% [markdown]
# ### Model 2

# %%
def gender_features2(name):
    features = {}
    # Last Letters 
    features["last_letter"] = name[-1].lower()
    features["last_2_letters"] = name[-2:].lower()
    #features["last_3_letters"] = name[-3:].lower()
    
    # First Letters 
    features["first_letter"] = name[:1].lower()
    features["first_2_letters"] = name[:2].lower()
    #features["first_3_letters"] = name[:3].lower()
    
    # Values
    features["has_A"] =  "a" in name.lower()
    features["has_E"] =  "e" in name.lower()
    features["has_I"] =  "i" in name.lower()
    features["has_O"] =  "o" in name.lower()
    features["has_U"] =  "u" in name.lower()
    features["has_Y"] =  "y" in name.lower()
    
    # Other Letters 
    features["has_l"] =  "l" in name.lower()
    features["has_s"] =  "s" in name.lower()
    features["has_t"] =  "t" in name.lower()
    features["has_r"] =  "r" in name.lower()
    features["has_n"] =  "n" in name.lower()
     
    return features

featuresets = [(gender_features2(n), g) for (n,g) in names]
 
test_set, dev_set, train_set = featuresets[:500],featuresets[500:1000],featuresets[1000:] 
classifier = nltk.NaiveBayesClassifier.train(train_set)

eval()
# Out:
# 0.8
# Most Informative Features
#           last_2_letters = 'na'           female : male   =    153.1 : 1.0
#           last_2_letters = 'la'           female : male   =     70.2 : 1.0
#              last_letter = 'k'              male : female =     45.1 : 1.0
#           last_2_letters = 'us'             male : female =     39.6 : 1.0
#           last_2_letters = 'ia'           female : male   =     38.2 : 1.0
#              last_letter = 'a'            female : male   =     34.4 : 1.0
#           last_2_letters = 'sa'           female : male   =     34.2 : 1.0
#           last_2_letters = 'rd'             male : female =     30.2 : 1.0
#              last_letter = 'f'              male : female =     26.6 : 1.0
#           last_2_letters = 'ra'           female : male   =     24.6 : 1.0

# %% [markdown]
# Removing first/last 3 did not improve our model at all.

# %% [markdown]
# ### Model 3

# %% [markdown]
# Lets next remove each of our single letter searches:

# %%
def gender_features2(name):
    features = {}
    # Last Letters 
    features["last_letter"] = name[-1].lower()
    features["last_2_letters"] = name[-2:].lower()
    features["last_3_letters"] = name[-3:].lower()
    
    # First Letters 
    features["first_letter"] = name[:1].lower()
    features["first_2_letters"] = name[:2].lower()
    features["first_3_letters"] = name[:3].lower()
    
    # Values
    #features["has_A"] =  "a" in name.lower()
    #features["has_E"] =  "e" in name.lower()
    #features["has_I"] =  "i" in name.lower()
    #features["has_O"] =  "o" in name.lower()
    #features["has_U"] =  "u" in name.lower()
    #features["has_Y"] =  "y" in name.lower()
    
    # Other Letters 
    #features["has_l"] =  "l" in name.lower()
    #features["has_s"] =  "s" in name.lower()
    #features["has_t"] =  "t" in name.lower()
    #features["has_r"] =  "r" in name.lower()
    #features["has_n"] =  "n" in name.lower()
     
    return features

featuresets = [(gender_features2(n), g) for (n,g) in names]

 
test_set, dev_set, train_set = featuresets[:500],featuresets[500:1000],featuresets[1000:] 
classifier = nltk.NaiveBayesClassifier.train(train_set)

eval()
# Out:
# 0.822
# Most Informative Features
#           last_2_letters = 'na'           female : male   =    153.1 : 1.0
#           last_2_letters = 'la'           female : male   =     70.2 : 1.0
#              last_letter = 'k'              male : female =     45.1 : 1.0
#           last_2_letters = 'us'             male : female =     39.6 : 1.0
#           last_2_letters = 'ia'           female : male   =     38.2 : 1.0
#              last_letter = 'a'            female : male   =     34.4 : 1.0
#           last_2_letters = 'sa'           female : male   =     34.2 : 1.0
#           last_2_letters = 'rd'             male : female =     30.2 : 1.0
#           last_3_letters = 'ard'            male : female =     27.7 : 1.0
#              last_letter = 'f'              male : female =     26.6 : 1.0

# %% [markdown]
# Removing the searches for individual levels (and adding back in the first/last 3) improved our model over removing the first/last 3 feature. That being said, this model is still slightly worse than our first attempt.

# %% [markdown]
# ## Maximum Entropy
#
# As our current best model with a 82.8% has several features which overlap. By definition, there is some overlap between 2 and 3 letter pairings, and our searches for a specific letter.
#
# Lets run a few Maxiumum Entropy models to see if we can not imporve our figure.

# %% [markdown]
# ### Model 4

# %%
def gender_features2(name):
    features = {}
    # Last Letters 
    features["last_letter"] = name[-1].lower()
    features["last_2_letters"] = name[-2:].lower()
    features["last_3_letters"] = name[-3:].lower()
    
    # First Letters 
    features["first_letter"] = name[:1].lower()
    features["first_2_letters"] = name[:2].lower()
    features["first_3_letters"] = name[:3].lower()
    
    # Values
    features["has_A"] =  "a" in name.lower()
    features["has_E"] =  "e" in name.lower()
    features["has_I"] =  "i" in name.lower()
    features["has_O"] =  "o" in name.lower()
    features["has_U"] =  "u" in name.lower()
    features["has_Y"] =  "y" in name.lower()
    
    # Other Letters 
    features["has_l"] =  "l" in name.lower()
    features["has_s"] =  "s" in name.lower()
    features["has_t"] =  "t" in name.lower()
    features["has_r"] =  "r" in name.lower()
    features["has_n"] =  "n" in name.lower()
     
    return features

featuresets = [(gender_features2(n), g) for (n,g) in names]

 
test_set, dev_set, train_set = featuresets[:500],featuresets[500:1000],featuresets[1000:] 
classifier = nltk.classify.MaxentClassifier.train(train_set)

eval()
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.370
#              2          -0.52193        0.665
#              3          -0.45443        0.798
#              4          -0.40689        0.844
#              5          -0.37247        0.856
#              6          -0.34666        0.863
#              7          -0.32665        0.869
#              8          -0.31068        0.873
#              9          -0.29760        0.877
#             10          -0.28667        0.882
#             11          -0.27737        0.883
#             12          -0.26933        0.886
#             13          -0.26230        0.887
#             14          -0.25608        0.890
#             15          -0.25052        0.892
#             16          -0.24551        0.894
#             17          -0.24096        0.895
#             18          -0.23680        0.896
#             19          -0.23299        0.898
#             20          -0.22946        0.900
#             21          -0.22619        0.902
#             22          -0.22315        0.903
#             23          -0.22030        0.904
#             24          -0.21763        0.905
#             25          -0.21511        0.905
#             26          -0.21274        0.906
#             27          -0.21050        0.907
#             28          -0.20837        0.908
#             29          -0.20635        0.909
#             30          -0.20442        0.910
#             31          -0.20259        0.910
#             32          -0.20084        0.910
#             33          -0.19916        0.911
#             34          -0.19755        0.911
#             35          -0.19601        0.912
#             36          -0.19453        0.913
#             37          -0.19311        0.913
#             38          -0.19174        0.914
#             39          -0.19041        0.914
#             40          -0.18914        0.915
#             41          -0.18791        0.915
#             42          -0.18672        0.915
#             43          -0.18557        0.915
#             44          -0.18446        0.915
#             45          -0.18338        0.915
#             46          -0.18233        0.916
#             47          -0.18132        0.916
#             48          -0.18033        0.916
#             49          -0.17938        0.916
#             50          -0.17845        0.916
#             51          -0.17755        0.917
#             52          -0.17667        0.918
#             53          -0.17581        0.917
#             54          -0.17498        0.918
#             55          -0.17417        0.918
#             56          -0.17338        0.918
#             57          -0.17261        0.918
#             58          -0.17185        0.918
#             59          -0.17112        0.918
#             60          -0.17040        0.918
#             61          -0.16970        0.919
#             62          -0.16902        0.918
#             63          -0.16835        0.918
#             64          -0.16770        0.918
#             65          -0.16706        0.918
#             66          -0.16643        0.918
#             67          -0.16582        0.919
#             68          -0.16522        0.919
#             69          -0.16464        0.919
#             70          -0.16406        0.918
#             71          -0.16350        0.919
#             72          -0.16295        0.919
#             73          -0.16241        0.919
#             74          -0.16188        0.919
#             75          -0.16136        0.919
#             76          -0.16085        0.920
#             77          -0.16035        0.920
#             78          -0.15986        0.920
#             79          -0.15938        0.920
#             80          -0.15891        0.920
#             81          -0.15844        0.920
#             82          -0.15799        0.921
#             83          -0.15754        0.921
#             84          -0.15710        0.921
#             85          -0.15666        0.921
#             86          -0.15624        0.921
#             87          -0.15582        0.921
#             88          -0.15541        0.921
#             89          -0.15500        0.921
#             90          -0.15461        0.921
#             91          -0.15422        0.921
#             92          -0.15383        0.921
#             93          -0.15345        0.921
#             94          -0.15308        0.921
#             95          -0.15271        0.921
#             96          -0.15235        0.921
#             97          -0.15199        0.922
#             98          -0.15164        0.922
#             99          -0.15130        0.922
#          Final          -0.15096        0.922
# 0.824
#    8.331 last_3_letters=='hna' and label is 'male'
#    7.553 first_3_letters=='eti' and label is 'male'
#    6.600 first_3_letters=='ira' and label is 'male'
#   -6.467 first_3_letters=='ros' and label is 'male'
#    6.266 last_3_letters=='coe' and label is 'male'
#   -5.789 last_2_letters=='na' and label is 'male'
#    5.730 last_3_letters=='tya' and label is 'male'
#    5.639 last_3_letters=='ous' and label is 'female'
#    5.537 last_3_letters=='rko' and label is 'male'
#   -5.481 last_letter=='k' and label is 'female'

# %% [markdown]
# We see above that there is significant overfitting. Our model was 92.2% accurate on the training set, but 82.4% on the dev set.
#
# We will try one more thing. We see above that the most predictive features are sets of 3 letters. I suspect these may be leading to overfitting, due to the realtively small quantity of names in the training set where each set of 3 letters can be found. By removing the first/last pairs of 3 from the model, we should have a lower accuracy on the training set, but a higher accuracy on the testing set.

# %% [markdown]
# ### Model 5

# %%
def gender_features2(name):
    features = {}
    # Last Letters 
    features["last_letter"] = name[-1].lower()
    features["last_2_letters"] = name[-2:].lower()
    #features["last_3_letters"] = name[-3:].lower()
    
    # First Letters 
    features["first_letter"] = name[:1].lower()
    features["first_2_letters"] = name[:2].lower()
    #features["first_3_letters"] = name[:3].lower()
    
    # Values
    features["has_A"] =  "a" in name.lower()
    features["has_E"] =  "e" in name.lower()
    features["has_I"] =  "i" in name.lower()
    features["has_O"] =  "o" in name.lower()
    features["has_U"] =  "u" in name.lower()
    features["has_Y"] =  "y" in name.lower()
    
    # Other Letters 
    features["has_l"] =  "l" in name.lower()
    features["has_s"] =  "s" in name.lower()
    features["has_t"] =  "t" in name.lower()
    features["has_r"] =  "r" in name.lower()
    features["has_n"] =  "n" in name.lower()
     
    return features

featuresets = [(gender_features2(n), g) for (n,g) in names]

 
test_set, dev_set, train_set = featuresets[:500],featuresets[500:1000],featuresets[1000:] 

classifier = nltk.classify.MaxentClassifier.train(train_set)

eval()
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.370
#              2          -0.54504        0.635
#              3          -0.49071        0.751
#              4          -0.45064        0.790
#              5          -0.42079        0.808
#              6          -0.39810        0.814
#              7          -0.38044        0.819
#              8          -0.36639        0.821
#              9          -0.35500        0.823
#             10          -0.34559        0.823
#             11          -0.33771        0.826
#             12          -0.33102        0.827
#             13          -0.32528        0.828
#             14          -0.32030        0.830
#             15          -0.31594        0.831
#             16          -0.31209        0.831
#             17          -0.30867        0.832
#             18          -0.30562        0.831
#             19          -0.30287        0.832
#             20          -0.30039        0.832
#             21          -0.29813        0.832
#             22          -0.29607        0.833
#             23          -0.29419        0.833
#             24          -0.29246        0.834
#             25          -0.29086        0.834
#             26          -0.28938        0.835
#             27          -0.28800        0.835
#             28          -0.28672        0.836
#             29          -0.28552        0.836
#             30          -0.28441        0.836
#             31          -0.28336        0.837
#             32          -0.28237        0.837
#             33          -0.28144        0.837
#             34          -0.28056        0.838
#             35          -0.27973        0.838
#             36          -0.27895        0.837
#             37          -0.27820        0.838
#             38          -0.27750        0.838
#             39          -0.27682        0.838
#             40          -0.27618        0.838
#             41          -0.27557        0.838
#             42          -0.27498        0.839
#             43          -0.27442        0.839
#             44          -0.27389        0.839
#             45          -0.27337        0.839
#             46          -0.27288        0.839
#             47          -0.27241        0.839
#             48          -0.27195        0.840
#             49          -0.27152        0.839
#             50          -0.27110        0.839
#             51          -0.27069        0.839
#             52          -0.27030        0.839
#             53          -0.26992        0.840
#             54          -0.26956        0.840
#             55          -0.26920        0.840
#             56          -0.26886        0.839
#             57          -0.26853        0.839
#             58          -0.26821        0.839
#             59          -0.26791        0.839
#             60          -0.26761        0.839
#             61          -0.26731        0.839
#             62          -0.26703        0.839
#             63          -0.26676        0.839
#             64          -0.26649        0.840
#             65          -0.26623        0.840
#             66          -0.26598        0.840
#             67          -0.26574        0.840
#             68          -0.26550        0.840
#             69          -0.26527        0.840
#             70          -0.26504        0.840
#             71          -0.26482        0.840
#             72          -0.26461        0.840
#             73          -0.26440        0.840
#             74          -0.26420        0.840
#             75          -0.26400        0.840
#             76          -0.26381        0.840
#             77          -0.26362        0.841
#             78          -0.26343        0.841
#             79          -0.26325        0.841
#             80          -0.26308        0.841
#             81          -0.26290        0.841
#             82          -0.26273        0.840
#             83          -0.26257        0.840
#             84          -0.26241        0.840
#             85          -0.26225        0.840
#             86          -0.26210        0.840
#             87          -0.26195        0.840
#             88          -0.26180        0.840
#             89          -0.26165        0.840
#             90          -0.26151        0.841
#             91          -0.26137        0.841
#             92          -0.26124        0.841
#             93          -0.26110        0.841
#             94          -0.26097        0.841
#             95          -0.26084        0.840
#             96          -0.26072        0.840
#             97          -0.26059        0.840
#             98          -0.26047        0.840
#             99          -0.26035        0.840
#          Final          -0.26024        0.840
# 0.81
#    5.984 last_2_letters=='ua' and label is 'male'
#   -5.723 last_letter=='k' and label is 'female'
#    4.860 last_2_letters=='bs' and label is 'female'
#    4.810 first_2_letters=='ll' and label is 'male'
#   -4.793 last_2_letters=='ko' and label is 'male'
#    4.724 last_2_letters=='oz' and label is 'female'
#    4.571 last_2_letters=='ru' and label is 'female'
#    4.515 last_2_letters=='ok' and label is 'female'
#   -4.503 last_letter=='f' and label is 'female'
#    4.252 first_2_letters=='dw' and label is 'male'

# %% [markdown]
# Well, this was actually one of our worst models. Depsite less overfitting, it was actually less accurate than our first model.

# %% [markdown]
# ## Conclusions / Testing Set Analysis

# %% [markdown]
# Despite several attempts to improve our model, our first model was the most accurate. A Naive Bayes model using factors based on the presence of the first and last 1/2/3 letters, as well as all vowels and the most common consonants was able to predict 82.8% of our Dev set.
#
# Lets see how it does on the testing set:

# %%
def gender_features2(name):
    features = {}
    # Last Letters 
    features["last_letter"] = name[-1].lower()
    features["last_2_letters"] = name[-2:].lower()
    features["last_3_letters"] = name[-3:].lower()
    
    # First Letters 
    features["first_letter"] = name[:1].lower()
    features["first_2_letters"] = name[:2].lower()
    features["first_3_letters"] = name[:3].lower()
    
    # Values
    features["has_A"] =  "a" in name.lower()
    features["has_E"] =  "e" in name.lower()
    features["has_I"] =  "i" in name.lower()
    features["has_O"] =  "o" in name.lower()
    features["has_U"] =  "u" in name.lower()
    features["has_Y"] =  "y" in name.lower()
    
    # Other Letters 
    features["has_l"] =  "l" in name.lower()
    features["has_s"] =  "s" in name.lower()
    features["has_t"] =  "t" in name.lower()
    features["has_r"] =  "r" in name.lower()
    features["has_n"] =  "n" in name.lower()
     
    return features

featuresets = [(gender_features2(n), g) for (n,g) in names]
test_set, dev_set, train_set = featuresets[:500],featuresets[500:1000],featuresets[1000:] 

nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.82

# %% [markdown]
# We see our first model was able to predict 82% on the training set.

# %%
classifier.show_most_informative_features(10)
# Out:
#    5.984 last_2_letters=='ua' and label is 'male'
#   -5.723 last_letter=='k' and label is 'female'
#    4.860 last_2_letters=='bs' and label is 'female'
#    4.810 first_2_letters=='ll' and label is 'male'
#   -4.793 last_2_letters=='ko' and label is 'male'
#    4.724 last_2_letters=='oz' and label is 'female'
#    4.571 last_2_letters=='ru' and label is 'female'
#    4.515 last_2_letters=='ok' and label is 'female'
#   -4.503 last_letter=='f' and label is 'female'
#    4.252 first_2_letters=='dw' and label is 'male'
