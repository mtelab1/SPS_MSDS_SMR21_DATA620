# %% [markdown]
# <b>Web Analytics DATA 620 - Project 02</b>
#
# <b>Assignment: “Wiki Publishing”</b>
#
# <b>Group - Chris Bloome / Mustafa Telab / Vinayak Kamath</b>
#
# <b>Date - 24th June 2021</b>
#
# ---
#
#
# Identify a large 2-node network dataset—you can start with a dataset in a repository.  Your data should meet the criteria that it consists of ties between and not within two (or more) distinct groups.
# Reduce the size of the network using a method such as the island method described in chapter 4 of social network analysis.
# What can you infer about each of the distinct groups?

# %% [markdown]
# ---

# %% [markdown]
# <b>Wikipedia User Publishing</b>

# %% [markdown]
# The source of the data is http://networkrepository.com/ia-wiki-user-edits-page.php#
#
# The data is a collection of edges that represent users and wikipedia pages; while the edges represent a edit events.
#
#  - User
#  - Web page
#  - Weight
#  - Time Stamp

# %% [markdown]
# ---

# %%
# Import required libraries
import networkx as nx
import networkx.algorithms.bipartite as bipartite
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyvis.network import Network
from datetime import datetime
from scipy.stats import zscore

# %%
df = pd.read_csv('ia-wiki-user-edits-page.edges', sep = ' ',header = None, names = ['source','target','weight','time'])

# %%
#df['hour'] = [int(datetime.utcfromtimestamp(v).strftime('%H')), for v in df['time']]
#df['month'] = [int(datetime.utcfromtimestamp(v).strftime('%m')) for v in df['time']]
#df['year'] = [int(datetime.utcfromtimestamp(v).strftime('%Y')) for v in df['time']]
df['date'] = [datetime.utcfromtimestamp(v).strftime('%Y-%m-%d') for v in df['time']]

# %%
df['hour'] = pd.to_datetime(df['date']).dt.strftime("%H")

# %%
df['source'] = ['u'+ str(v) for v in df['source']]
df['target'] = ['p'+ str(v) for v in df['target']]

# %%
df['date'] = pd.to_datetime(df['date'])
maxyear = df['date'].dt.year.max()

# %%
df = df[df['date'].dt.year == maxyear]
print(len(df))
# Out:
# 1873945

# %%
u198 = df[df['source']=='u198'].groupby('date').aggregate({('weight'):np.sum}).sort_values(by = 'date', ascending = True).reset_index()

# %%
u198['date'] = pd.to_datetime(u198['date'], format = '%Y-%m-%d')
r = pd.date_range(start= u198.date.min(), end = u198.date.max())
u198 = u198.set_index('date').reindex(r, fill_value=0)#.reindex(r)#.fillna(0).rename_axis('date').reset_index()

# %%
plt.plot(r,pd.Series(u198['weight']).cumsum())
plt.xticks([min(r), max(r)])
plt.show()
# Out:
# /Users/mustafatelab/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/mustafatelab/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/mustafatelab/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/axes/_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
df_frequency_step = df.groupby(['source','date']).aggregate({('weight'):np.sum}).sort_values('weight').reset_index()

# %%
df_frequency = df_frequency_step.groupby(['source']).aggregate({('weight'):np.average}).sort_values('weight').reset_index()

# %%
df_frequency.columns = ['source', 'frequency']
df_frequency
# Out:
#       source     frequency
# 0      u9999      1.000000
# 1     u20535      1.000000
# 2     u20537      1.000000
# 3     u20544      1.000000
# 4     u29112      1.000000
# ...      ...           ...
# 5158   u1405    889.338710
# 5159    u198   1603.626556
# 5160  u18229   2388.636364
# 5161    u232   2647.189189
# 5162    u680  13261.375000
#
# [5163 rows x 2 columns]

# %%
plt.hist(df_frequency['frequency'], bins = 100 )
plt.yscale('log')
plt.show()

# %%
plt.plot(df_frequency.index, df_frequency.frequency)
plt.show()
# Out:
# /Users/mustafatelab/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/pandas/core/indexes/range.py:780: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return super().__getitem__(key)
# /Users/mustafatelab/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/mustafatelab/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/axes/_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
df_grouped = df.groupby(['source','target']).aggregate({('weight'):np.sum}).reset_index()
#,('date'):np.average,('month'):np.average

# %%
u_count = df_grouped['source'].value_counts(ascending=True).rename_axis('source').reset_index(name='pages')
p_count = df_grouped['target'].value_counts(ascending=True).rename_axis('target').reset_index(name='users')

# %%
p_count
# Out:
#            target  users
# 0        p1360075      1
# 1        p1693336      1
# 2        p1577044      1
# 3        p1458539      1
# 4        p1150526      1
# ...           ...    ...
# 1022339  p1936168    108
# 1022340      p590    121
# 1022341   p117268    128
# 1022342   p183627    135
# 1022343   p348358    140
#
# [1022344 rows x 2 columns]

# %%
u_count
# Out:
#       source   pages
# 0     u19136       1
# 1     u19146       1
# 2      u5419       1
# 3     u28504       1
# 4     u20119       1
# ...      ...     ...
# 5158    u232   88549
# 5159    u193  111403
# 5160    u845  134132
# 5161    u680  212041
# 5162    u198  304980
#
# [5163 rows x 2 columns]

# %%
df_grouped = pd.merge(df_grouped, u_count, how="left", on="source")
df_grouped = pd.merge(df_grouped, p_count, how="left", on="target")
df_grouped = pd.merge(df_grouped, df_frequency, how="left", on="source")

# %%
user_stats = u_count["pages"].describe().round(2)
page_stats = p_count["users"].describe().round(2)
freq_stats = df_frequency["frequency"].describe().round(2)
print('Pages Per User Statisitics')
print(user_stats, '\n')
print('Users Per Page Statisitics')
print(page_stats, '\n')
print('Edit Daily Frequency Statisitics')
print(freq_stats)
# Out:
# Pages Per User Statisitics
# count      5163.00
# mean        292.04
# std        6012.43
# min           1.00
# 25%           1.00
# 50%           1.00
# 75%           4.00
# max      304980.00
# Name: pages, dtype: float64
#
# Users Per Page Statisitics
# count    1022344.00
# mean           1.47
# std            1.11
# min            1.00
# 25%            1.00
# 50%            1.00
# 75%            2.00
# max          140.00
# Name: users, dtype: float64
#
# Edit Daily Frequency Statisitics
# count     5163.00
# mean         8.15
# std        193.70
# min          1.00
# 25%          1.00
# 50%          1.40
# 75%          2.71
# max      13261.38
# Name: frequency, dtype: float64

# %%
plt.hist(u_count['pages'], bins = 10)
plt.title('Pages Per User Statisitics')
plt.yscale('log')

# %%
plt.hist(p_count['users'], bins = 30)
plt.title('Users Per Page Statisitics')
plt.yscale('log')

# %%
print(len(df_grouped))
print(df_grouped.head())
# Out:
# 1507809
#   source    target  weight  pages  users  frequency
# 0    u10   p151715       1     11      4      1.875
# 1    u10    p15829       2     11      2      1.875
# 2    u10  p1668464       9     11      3      1.875
# 3    u10   p348358       4     11    140      1.875
# 4    u10    p35699       1     11     13      1.875

# %%
freq_std = freq_stats['std']
user_min = user_stats['75%']
page_min = page_stats['75%']
df_island = df_grouped[(df_grouped['pages']>user_min)  & (df_grouped['users']>page_min) & (df_grouped['frequency'] < (freq_std * 5))]
len(df_island)
# Out:
# 249731

# %%
S = nx.from_pandas_edgelist(df_island, source='source', target='target', edge_attr=["weight"], create_using = nx.DiGraph(), edge_key=None)

# %%
print(nx.info(S))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 85611
# Number of edges: 249731
# Average in degree:   2.9170
# Average out degree:   2.9170

# %%
len(list(nx.connected_components(S.to_undirected())))
# Out:
# 1

# %%
users = [v for v in S.nodes() if v[0]== 'u']
len(users)
# Out:
# 1092

# %%
pages = [v for v in S.nodes() if v[0]== 'p']
len(pages)
# Out:
# 84519

# %%
#P = bipartite.projected_graph(S.to_undirected(), pages)

# %%
U = bipartite.projected_graph(S.to_undirected(), users)

# %%
bipartite.collaboration_weighted_projected_graph(B, [0, 2, 4, 5])

# %%
print(nx.info(U))
# Out:
# Name:
# Type: Graph
# Number of nodes: 1092
# Number of edges: 59775
# Average degree: 109.4780

# %%
sorted(nx.degree_centrality(U).items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('u193', 0.9184234647112741),
#  ('u203', 0.8652612282309807),
#  ('u134', 0.8075160403299725),
#  ('u25', 0.7341888175985335),
#  ('u239', 0.7222731439046747),
#  ('u333', 0.7048579285059579),
#  ('u106', 0.6691109074243813),
#  ('u83', 0.6553620531622365),
#  ('u240', 0.6443629697525206),
#  ('u79', 0.6379468377635197)]

# %%
sorted(dict(U.to_undirected().degree()).items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('u193', 1002),
#  ('u203', 944),
#  ('u134', 881),
#  ('u25', 801),
#  ('u239', 788),
#  ('u333', 769),
#  ('u106', 730),
#  ('u83', 715),
#  ('u240', 703),
#  ('u79', 696)]

# %%
sorted(dict(nx.eigenvector_centrality(U)).items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('u134', 0.09340336731347809),
#  ('u193', 0.09255061273093777),
#  ('u203', 0.09099597505856727),
#  ('u25', 0.09075453030227688),
#  ('u239', 0.09046800680651776),
#  ('u333', 0.0896613437121025),
#  ('u106', 0.08914981227607732),
#  ('u240', 0.08799379721899583),
#  ('u83', 0.08776248430376145),
#  ('u79', 0.08761221274741664)]

# %%
density = nx.density(U)
print(density)
print(nx.is_connected(U.to_undirected()))
# Out:
# 0.10034649127224746
# True

# %%
U_degrees = dict(U.degree()).values()
plt.hist(U_degrees, bins = 30)
# Out:
# (array([446., 152., 117.,  91.,  65.,  41.,  30.,  28.,  29.,  16.,  11.,
#           9.,   5.,   6.,   7.,  10.,   3.,   4.,   7.,   4.,   2.,   3.,
#           0.,   3.,   0.,   0.,   1.,   0.,   1.,   1.]),
#  array([1.00000000e+00, 3.43666667e+01, 6.77333333e+01, 1.01100000e+02,
#         1.34466667e+02, 1.67833333e+02, 2.01200000e+02, 2.34566667e+02,
#         2.67933333e+02, 3.01300000e+02, 3.34666667e+02, 3.68033333e+02,
#         4.01400000e+02, 4.34766667e+02, 4.68133333e+02, 5.01500000e+02,
#         5.34866667e+02, 5.68233333e+02, 6.01600000e+02, 6.34966667e+02,
#         6.68333333e+02, 7.01700000e+02, 7.35066667e+02, 7.68433333e+02,
#         8.01800000e+02, 8.35166667e+02, 8.68533333e+02, 9.01900000e+02,
#         9.35266667e+02, 9.68633333e+02, 1.00200000e+03]),
#  <a list of 30 Patch objects>)

# %%
nx.draw(U)

# %%
#modifiction of code clock found on Social Network Analysis for Startups, pg64 
def trim_nodes(g, weight=1):
    nodes = []
    for n in g.nodes():
        if g.degree(n) > weight:
            nodes.append(n)
    G2 = g.subgraph(nodes)
    return G2

# %%
U2 = trim_nodes(U,100)
print(nx.info(U2))
# Out:
# Name:
# Type: Graph
# Number of nodes: 378
# Number of edges: 36719
# Average degree: 194.2804

# %%
U2_degrees = dict(U2.degree()).values()
fig, ax = plt.subplots(figsize=(15, 15))
nx.draw_spring(U2 ,alpha =.7,width = .01, arrows=False , node_size = [v*.3 for v in U2_degrees])

# %%
W = bipartite.overlap_weighted_projected_graph(S.to_undirected(),list(U2.nodes()))

# %%
print(nx.info(W))
# Out:
# Name:
# Type: Graph
# Number of nodes: 1092
# Number of edges: 58653
# Average degree: 107.4231

# %%
W_degrees = dict(W.degree()).values()
fig, ax = plt.subplots(figsize=(15, 15))
nx.draw_spring(W ,alpha =.7,width = .01, arrows=False , node_size = [v*.3 for v in W_degrees])

# %%
W2 = trim_nodes(W,100)
print(nx.info(W2))
# Out:
# Name:
# Type: Graph
# Number of nodes: 378
# Number of edges: 36719
# Average degree: 194.2804

# %%
W2_degrees = dict(W2.degree()).values()
W2_weights = nx.get_edge_attributes(W2, 'weight').values()
fig, ax = plt.subplots(figsize=(15, 15))
nx.draw_spring(W2 ,alpha =.7,width = W2_weights, arrows=False , node_size = [v*.3 for v in W_degrees])
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f874e091f80> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     335                 self._linewidths, self._linestyles,
#     336                 self._antialiaseds, self._urls,
# --> 337                 self._offset_position)
#     338
#     339         gc.restore()
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_path_collection(self, *kl, **kw)
#     127
#     128     def draw_path_collection(self, *kl, **kw):
# --> 129         return self._renderer.draw_path_collection(*kl, **kw)
#     130
#     131     def _update_methods(self):
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     335                 self._linewidths, self._linestyles,
#     336                 self._antialiaseds, self._urls,
# --> 337                 self._offset_position)
#     338
#     339         gc.restore()
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_path_collection(self, *kl, **kw)
#     127
#     128     def draw_path_collection(self, *kl, **kw):
# --> 129         return self._renderer.draw_path_collection(*kl, **kw)
#     130
#     131     def _update_methods(self):
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'

# %%
nx.get_edge_attributes(W2, 'weight').values()
# Out:
# dict_values([0.0029498525073746312, 0.004721435316336166, 0.007575757575757576, 0.003968253968253968, 0.0032679738562091504, 0.003745318352059925, 0.0043859649122807015, 0.005952380952380952, 0.01098901098901099, 8.410428931875525e-05, 0.03773584905660377, 0.0029239766081871343, 0.001892147587511826, 0.0022271714922048997, 0.0015657620041753654, 0.0038910505836575876, 0.002150537634408602, 0.0015082956259426848, 0.00851063829787234, 0.009287925696594427, 0.004366812227074236, 0.0044444444444444444, 0.003968253968253968, 0.004032258064516129, 0.0022935779816513763, 0.004784688995215311, 0.002913752913752914, 0.010362694300518135, 0.0023148148148148147, 0.02643171806167401, 0.010726325467361323, 0.003401360544217687, 0.0028089887640449437, 0.004672897196261682, 0.0017211703958691911, 0.0048543689320388345, 0.0014566642388929353, 0.0021390374331550803, 0.006493506493506494, 0.004433833560709414, 0.009041591320072333, 0.0064516129032258064, 0.003701418877236274, 0.0034627751669552313, 0.0026298487836949377, 0.0017548365005992125, 0.0034129692832764505, 0.007751937984496124, 0.007142857142857143, 0.005434782608695652, 0.0028704700394689632, 0.0018509949097639982, 0.005494505494505495, 0.0038910505836575876, 0.007518796992481203, 0.046948356807511735, 0.001567398119122257, 0.007905138339920948, 0.004201680672268907, 0.001762114537444934, 0.002540220152413209, 0.002407318247472316, 0.01098901098901099, 0.006042296072507553, 0.001364256480218281, 0.006134969325153374, 0.009569377990430622, 0.10714285714285714, 0.002352941176470588, 0.003069367710251688, 0.006309148264984227, 0.007874015748031496, 0.0012547051442910915, 0.0037174721189591076, 0.006024096385542169, 0.0017906560312550871, 0.007079646017699115, 0.005805515239477504, 0.0013845621322256837, 0.008438818565400843, 0.00851063829787234, 0.0064516129032258064, 0.003393665158371041, 0.004830917874396135, 0.0039126181936746, 0.002849002849002849, 0.001786511835640911, 0.004640371229698376, 0.001279863481228669, 0.006172839506172839, 0.0031746031746031746, 0.017954070981210855, 0.003952569169960474, 0.003928679359323058, 0.008403361344537815, 0.0013197586726998493, 0.012448132780082987, 0.0031746031746031746, 0.0075675675675675675, 0.004469273743016759, 0.0014169323414806943, 0.008695652173913044, 0.00804289544235925, 0.005089058524173028, 0.009174311926605505, 0.00273224043715847, 0.0022471910112359553, 0.00796812749003984, 0.002805049088359046, 0.006097560975609756, 0.0010893246187363835, 0.01051122790253225, 0.0021008403361344537, 0.0045016077170418, 0.0009149130832570906, 0.0058823529411764705, 0.004499678594386115, 0.004672897196261682, 0.0018961339934688718, 0.001437297879985627, 0.0002623983206507478, 0.004608294930875576, 0.002325581395348837, 0.007194244604316547, 0.005649717514124294, 0.005847953216374269, 0.0031512605042016808, 0.001440922190201729, 0.0018552875695732839, 0.005702066999287242, 0.003134796238244514, 0.0051813471502590676, 0.00145985401459854, 0.005714285714285714, 0.007751937984496124, 0.007952286282306162, 0.006320224719101123, 0.006060606060606061, 0.009569377990430622, 0.004424778761061947, 0.002126754572522331, 0.00319693094629156, 0.0033257119102057782, 0.0028530670470756064, 0.003651300775901415, 0.00530035335689046, 0.007281553398058253, 0.016129032258064516, 0.005660377358490566, 0.0035087719298245615, 0.017119838872104734, 0.010309278350515464, 0.00547302580140735, 0.022573363431151242, 0.016129032258064516, 0.011627906976744186, 0.037383177570093455, 0.015151515151515152, 0.015384615384615385, 0.015384615384615385, 0.009933774834437087, 0.013513513513513514, 0.026415094339622643, 0.03125, 0.022988505747126436, 0.005847953216374269, 0.03488372093023256, 0.014084507042253521, 0.02680965147453083, 0.002028397565922921, 0.005336179295624333, 0.006642512077294686, 0.007142857142857143, 0.002777777777777778, 0.011904761904761904, 0.0015527950310559005, 0.016778523489932886, 0.009280742459396751, 0.003616636528028933, 0.02403846153846154, 0.01515151515 ...

# %%
W2_weights.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-a376817f2e0e> in <module>
# ----> 1 W2_weights.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
__author__ = """\n""".join(['Maksim Tsvetovat <maksim@tsvetovat.org',
'Drew Conway <drew.conway@nyu.edu>',
'Aric Hagberg <hagberg@lanl.gov>'])
from collections import defaultdict
import networkx as nx
import numpy
from scipy.cluster import hierarchy
from scipy.spatial import distance
import matplotlib.pyplot as plt

def create_hc(G, t=1.0):
    """
    Creates hierarchical cluster of graph G from distance matrix
    Maksim Tsvetovat ->> Generalized HC pre- and post-processing to work on labelled graphs
    and return labelled clusters
    The threshold value is now parameterized; useful range should be determined
    experimentally with each dataset
    """
    """Modified from code by Drew Conway"""
    
    ## Create a shortest-path distance matrix, while preserving node labels
    labels=G.nodes()
    path_length=nx.all_pairs_shortest_path_length(G)
    distances=numpy.zeros((len(G),len(G)))
    i=0
    for u,p in path_length:
        j=0
        for v,d in p.items():
            distances[i][j]=d
            distances[j][i]=d
            if i==j: distances[i][j]=0
            j+=1
        i+=1
        
    # Create hierarchical cluster
    Y=distance.squareform(distances)
    Z=hierarchy.complete(Y) # Creates HC using farthest point linkage
    
    # This partition selection is arbitrary, for illustrive purposes
    membership=list(hierarchy.fcluster(Z,t=t))
    
    # Create collection of lists for blockmodel
    partition=defaultdict(list)
    for n,p in zip(list(range(len(G))),membership):
        if p>=0:
            partition[p].append(labels[n])
    return list(partition.values())

# %%
#clusters = create_hc(U2)
