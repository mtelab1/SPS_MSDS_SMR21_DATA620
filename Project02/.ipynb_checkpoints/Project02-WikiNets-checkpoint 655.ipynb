# %% [markdown]
# <b>Web Analytics DATA 620 - Project 02</b>
#
# <b>Assignment: “Wiki Publishing”</b>
#
# <b>Group - Chris Bloome / Mustafa Telab / Vinayak Kamath</b>
#
# <b>Date - 24th June 2021</b>
#
# ---
#
#
# Identify a large 2-node network dataset—you can start with a dataset in a repository.  Your data should meet the criteria that it consists of ties between and not within two (or more) distinct groups.
# Reduce the size of the network using a method such as the island method described in chapter 4 of social network analysis.
# What can you infer about each of the distinct groups?

# %% [markdown]
# ---

# %% [markdown]
# <b>Wikipedia User Publishing</b>

# %% [markdown]
# The source of the data is http://networkrepository.com/ia-wiki-user-edits-page.php#
#
# The data is a collection of edges that represent users and wikipedia pages; while the edges represent a edit events.
#
#  - User
#  - Web page
#  - Weight
#  - Time Stamp

# %% [markdown]
# ---

# %% [markdown]
# <b>Plan</b>

# %% [markdown]
#  1. Import and explore the edge data.
#  2. Identify opportunities to filter out irrelevant data.
#  3. Incorporate the "island" method to isolate the meaningful clusters
#  4. Apply appropriate bipartite weights to visualize important edges.

# %% [markdown]
# ---

# %% [markdown]
# # Data Cleaning

# %%
# Import required libraries
import networkx as nx
import networkx.algorithms.bipartite as bipartite
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyvis.network import Network
from datetime import datetime
from scipy.stats import zscore
from tabulate import tabulate
from networkx.drawing.nx_pydot import graphviz_layout

# %%
#Import Dataset
df = pd.read_csv('ia-wiki-user-edits-page.edges', sep = ' ',header = None, names = ['source','target','weight','time'])

# %%
#Convert timestamp to datetime format
df['date'] = [datetime.utcfromtimestamp(v).strftime('%Y-%m-%d') for v in df['time']]

# %%
df['hour'] = pd.to_datetime(df['date']).dt.strftime("%H")

# %%
#tag nodes to distiguish later
df['source'] = ['u'+ str(v) for v in df['source']]
df['target'] = ['p'+ str(v) for v in df['target']]

# %%
#Filter to include only latest years data
df['date'] = pd.to_datetime(df['date'])
maxyear = df['date'].dt.year.max()
df = df[df['date'].dt.year == maxyear]
print(len(df))
# Out:
# 1873945

# %%
#With repeat edits common, we can roll the values to a single edge and assign the count to the 'weight' attribute
df_grouped = df.groupby(['source','target']).aggregate({('weight'):np.sum}).reset_index()

# %% [markdown]
# # Exploration
# With other a million edge, we will examine the data set in a pandas dataset before reading into a graph

# %%
#Calculate the degrees for the users and pages
u_count = df_grouped['source'].value_counts(ascending=True).rename_axis('source').reset_index(name='pages')
p_count = df_grouped['target'].value_counts(ascending=True).rename_axis('target').reset_index(name='users')

# %%
p_count
# Out:
#            target  users
# 0         p885872      1
# 1        p1975403      1
# 2        p1907565      1
# 3        p1817803      1
# 4        p1694543      1
# ...           ...    ...
# 1022339  p1936168    108
# 1022340      p590    121
# 1022341   p117268    128
# 1022342   p183627    135
# 1022343   p348358    140
#
# [1022344 rows x 2 columns]

# %%
u_count
# Out:
#       source   pages
# 0     u29107       1
# 1     u19415       1
# 2     u17943       1
# 3     u17296       1
# 4     u25317       1
# ...      ...     ...
# 5158    u232   88549
# 5159    u193  111403
# 5160    u845  134132
# 5161    u680  212041
# 5162    u198  304980
#
# [5163 rows x 2 columns]

# %% [markdown]
# We notice that some users has degrees in the hundreds of thousands.  It is understood that WIkipedia enlists the help of Bots to maintain many of the pages.  Lets examine the daily frequency of edits to establish a humanly feasible cut-off so we can filter out the bots.

# %%
df_frequency_step = df.groupby(['source','date']).aggregate({('weight'):np.sum}).sort_values('weight').reset_index()

# %%
df_frequency = df_frequency_step.groupby(['source']).aggregate({('weight'):np.average}).sort_values('weight').reset_index()

# %%
df_frequency.columns = ['source', 'frequency']
df_frequency
# Out:
#       source     frequency
# 0      u9999      1.000000
# 1     u20535      1.000000
# 2     u20537      1.000000
# 3     u20544      1.000000
# 4     u29112      1.000000
# ...      ...           ...
# 5158   u1405    889.338710
# 5159    u198   1603.626556
# 5160  u18229   2388.636364
# 5161    u232   2647.189189
# 5162    u680  13261.375000
#
# [5163 rows x 2 columns]

# %%
plt.hist(df_frequency['frequency'], bins = 100 )
plt.yscale('log')
plt.show()

# %% [markdown]
# The frequency distribition shows that the bots are easily distriguishable from just a few multiples of std.

# %%
freq_stats = df_frequency["frequency"].describe().round(2)
print('Edit Daily Frequency Statisitics')
print(freq_stats)
# Out:
# Edit Daily Frequency Statisitics
# count     5163.00
# mean         8.15
# std        193.70
# min          1.00
# 25%          1.00
# 50%          1.40
# 75%          2.71
# max      13261.38
# Name: frequency, dtype: float64

# %%
plt.hist(u_count['pages'], bins = 10)
plt.title('Pages Per User Statisitics')
plt.yscale('log')

# %%
user_stats = u_count["pages"].describe().round(2)
print('Pages Per User Statisitics')
print(user_stats, '\n')
# Out:
# Pages Per User Statisitics
# count      5163.00
# mean        292.04
# std        6012.43
# min           1.00
# 25%           1.00
# 50%           1.00
# 75%           4.00
# max      304980.00
# Name: pages, dtype: float64

# %%
plt.hist(p_count['users'], bins = 30)
plt.title('Users Per Page Statisitics')
plt.yscale('log')

# %%
page_stats = p_count["users"].describe().round(2)
print('Users Per Page Statisitics')
print(page_stats, '\n')
# Out:
# Users Per Page Statisitics
# count    1022344.00
# mean           1.47
# std            1.11
# min            1.00
# 25%            1.00
# 50%            1.00
# 75%            2.00
# max          140.00
# Name: users, dtype: float64

# %%
df_grouped = pd.merge(df_grouped, u_count, how="left", on="source")
df_grouped = pd.merge(df_grouped, p_count, how="left", on="target")
df_grouped = pd.merge(df_grouped, df_frequency, how="left", on="source")

# %%
print(len(df_grouped))
print(df_grouped.head())
# Out:
# 1507809
#   source    target  weight  pages  users  frequency
# 0    u10   p151715       1     11      4      1.875
# 1    u10    p15829       2     11      2      1.875
# 2    u10  p1668464       9     11      3      1.875
# 3    u10   p348358       4     11    140      1.875
# 4    u10    p35699       1     11     13      1.875

# %% [markdown]
# ## Island Method
# While still in the pandas format, we will enlist the island method by filtering the edges to include only most active users and pages; while simultaniuosly removing the uber active users, which we have already determined are bots.

# %%
#Set "water levels"
freq_std = freq_stats['std']
user_min = user_stats['75%']
page_min = page_stats['75%']
#apply filter
df_island = df_grouped[(df_grouped['pages']>user_min)  & (df_grouped['users']>page_min) & (df_grouped['frequency'] < (freq_std * 5))]

# %%
print('From the above steps, we have reduced a list of almost', len(df), 'edges to', len(df_island))
# Out:
# From the above steps, we have reduced a list of almost 1873945 edges to 249731

# %% [markdown]
# ## Establish initial graph

# %%
S = nx.from_pandas_edgelist(df_island, source='source', target='target', edge_attr=["weight"], create_using = nx.DiGraph(), edge_key=None)

# %%
print(nx.info(S))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 85611
# Number of edges: 249731
# Average in degree:   2.9170
# Average out degree:   2.9170

# %%
nx.diameter(S)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-26-165accc62cbd> in <module>
# ----> 1 nx.diameter(S)
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/networkx/algorithms/distance_measures.py in diameter(G, e, usebounds)
#     297         return extrema_bounding(G, compute="diameter")
#     298     if e is None:
# --> 299         e = eccentricity(G)
#     300     return max(e.values())
#     301
#
# ~/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/networkx/algorithms/distance_measures.py in eccentricity(G, v, sp)
#     262             else:
#     263                 msg = "Found infinite path length because the graph is not" " connected"
# --> 264             raise nx.NetworkXError(msg)
#     265
#     266         e[n] = max(length.values())
#
# NetworkXError: Found infinite path length because the digraph is not strongly connected

# %%
users = [v for v in S.nodes() if v[0]== 'u']
len(users)
# Out:
# 1092

# %%
pages = [v for v in S.nodes() if v[0]== 'p']
len(pages)
# Out:
# 84519

# %%
#P = bipartite.projected_graph(S.to_undirected(), pages)

# %%
U = bipartite.projected_graph(S.to_undirected(), users)

# %%
bipartite.collaboration_weighted_projected_graph(B, [0, 2, 4, 5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-eb7455a7ed0a> in <module>
# ----> 1 bipartite.collaboration_weighted_projected_graph(B, [0, 2, 4, 5])
#
# NameError: name 'B' is not defined

# %% [markdown]
# Now we review the size of the first pass of the island method.

# %%
print(nx.info(U))
# Out:
# Name:
# Type: Graph
# Number of nodes: 1092
# Number of edges: 59775
# Average degree: 109.4780

# %%
density = nx.density(U)
print(density)
print(nx.is_connected(U.to_undirected()))
# Out:
# 0.10034649127224746
# True

# %%
U_degrees = dict(U.degree()).values()
plt.hist(U_degrees, bins = 30)
# Out:
# (array([446., 152., 117.,  91.,  65.,  41.,  30.,  28.,  29.,  16.,  11.,
#           9.,   5.,   6.,   7.,  10.,   3.,   4.,   7.,   4.,   2.,   3.,
#           0.,   3.,   0.,   0.,   1.,   0.,   1.,   1.]),
#  array([1.00000000e+00, 3.43666667e+01, 6.77333333e+01, 1.01100000e+02,
#         1.34466667e+02, 1.67833333e+02, 2.01200000e+02, 2.34566667e+02,
#         2.67933333e+02, 3.01300000e+02, 3.34666667e+02, 3.68033333e+02,
#         4.01400000e+02, 4.34766667e+02, 4.68133333e+02, 5.01500000e+02,
#         5.34866667e+02, 5.68233333e+02, 6.01600000e+02, 6.34966667e+02,
#         6.68333333e+02, 7.01700000e+02, 7.35066667e+02, 7.68433333e+02,
#         8.01800000e+02, 8.35166667e+02, 8.68533333e+02, 9.01900000e+02,
#         9.35266667e+02, 9.68633333e+02, 1.00200000e+03]),
#  <a list of 30 Patch objects>)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
nx.draw(U)

# %% [markdown]
# The above graph does not offer any insights, so we move forward by again trimming nodes by a certain degree threshold.

# %%
#modifiction of code clock found on Social Network Analysis for Startups, pg64 
def trim_nodes(g, weight=1):
    nodes = []
    for n in g.nodes():
        if g.degree(n) > weight:
            nodes.append(n)
    G2 = g.subgraph(nodes)
    return G2

# %%
U2 = trim_nodes(U,100)
print(nx.info(U2))
# Out:
# Name:
# Type: Graph
# Number of nodes: 378
# Number of edges: 36719
# Average degree: 194.2804

# %%
U2_degrees = dict(U2.degree()).values()
fig, ax = plt.subplots(figsize=(15, 15))
nx.draw_spring(U2 ,alpha =.7,width = .01, arrows=False , node_size = [v*.3 for v in U2_degrees])

# %% [markdown]
# The above graph is an improvement, but lets see what the results are when we project these nodes using the weighted overlap metho

# %%
W = bipartite.overlap_weighted_projected_graph(S.to_undirected(),list(U2.nodes()))

# %%
print(nx.info(W))
# Out:
# Name:
# Type: Graph
# Number of nodes: 1092
# Number of edges: 58653
# Average degree: 107.4231

# %%
W_degrees = dict(W.degree()).values()
fig, ax = plt.subplots(figsize=(15, 15))
nx.draw_spring(W ,alpha =.7,width = .01, arrows=False , node_size = [v*.3 for v in W_degrees])

# %%
W2 = trim_nodes(W,100)
print(nx.info(W2))
# Out:
# Name:
# Type: Graph
# Number of nodes: 378
# Number of edges: 36719
# Average degree: 194.2804

# %%
W2_stats = pd.Series(W2_weights).describe().round(2)

# %%
W2_degrees = dict(W2.degree()).values()
W2_weights = [v*10 for v in nx.get_edge_attributes(W2, 'weight').values()]
fig, ax = plt.subplots(figsize=(15, 15))
nx.draw(W2 ,alpha =.7,width = W2_weights, arrows=False , node_size = [v*.3 for v in W_degrees])

# %%
#modifiction of code clock found on Social Network Analysis for Startups, pg64 
def trim_edges(g, weight=1):
    l = []
    g2 = g.copy(as_view=False)
    for f, to, edata in g.edges(data=True):
            if edata['weight'] < weight:
                l.append((f,to))
    g2.remove_edges_from(l)
    g3 = nx.subgraph(g2, list(nx.connected_components(g2))[0])
    return g3

# %%
W3 = trim_edges(W2, W2_stats['50%']/3)
#print(nx.info(W3))

# %%
len(list(nx.connected_components(W3))[0])
# Out:
# 370

# %%
W3_centralities = get_centrality_ranks(W3,30)
W3_centralities[:40]
# Out:
#       Node  Degrees  Degree_Centrality  Eigenvector  Betweeness  Closeness
# 0     u302        0                  0            0           8          5
# 1     u176        1                  1            2           1          0
# 2    u1081        2                  2            3           5          4
# 3    u3192        3                  3            1          17          6
# 4     u655        4                  4            5           2          2
# 5    u2455        5                  5            4          22          9
# 6    u2379        6                  6            6          40         10
# 7    u1432        7                  7           11           4          3
# 8    u8920        8                  8            7          56         31
# 9     u207       12                 12           43           0          1
# 10   u1461        9                  9           10          25         19
# ...

# %%
W3_cent_vals = get_centrality_values(W3,10)

# %%
df_temp = W3_cent_vals.join(W3_cent_vals[W3_cent_vals.select_dtypes(include=[np.number]).columns].apply(zscore), how = 'right', rsuffix = '_z')

# %%
df_temp['measure'] = df_temp['Degree_Centrality_z']/df_temp['Betweeness_z']

# %%
dfmin = df_temp['measure'].min()
df_temp['measure'] = df_temp['measure'] + (0-dfmin)
df_temp['measure']
# Out:
# 0      29.004380
# 1      27.909008
# 2      28.398643
# 3      29.479061
# 4      28.030670
#          ...
# 271    27.527077
# 272    27.831000
# 273    28.028398
# 274    27.974492
# 275    28.088835
# Name: measure, Length: 276, dtype: float64

# %%
W3_top = W3_centralities.iloc[:30,0]

# %%
W3_pos = nx.kamada_kawai_layout(W3)

# %%
import math as m

W3_degrees = dict(W3.degree()).values()
W3_weights = [v*5 for v in nx.get_edge_attributes(W3, 'weight').values()]
W3_ncol = [v*5 for v in nx.betweenness_centrality(W3).values()]
W3_ecol = [v*50 for v in nx.get_edge_attributes(W3, 'weight').values()]
W3_labels = {v : v  for v in W3.nodes() if v in iter(W3_top) }
W3_pos = nx.spring_layout(W3, seed = 11103)
#W3_pos_tf = {k : v/((1+np.linalg.norm(v))**1.7) for k,v in W3_pos.items()}


fig, ax = plt.subplots(figsize=(15, 15))
#plt.margins(x=-.25, y=-0.25)
nx.draw(W3 ,pos = W3_pos, alpha =.7, width = W3_weights, arrows=False ,edge_color= W3_ecol,edge_cmap = plt.cm.spring, node_size = [v*.7 for v in W3_degrees],node_color=W3_ncol, cmap =plt.cm.winter , with_labels = True, labels = W3_labels,font_size =20)
#label_options = {"ec": "k", "fc": "white", "alpha": 0.7}
#nx.draw_networkx_labels(W3_labels, font_size=14, bbox=label_options)
#, with_labels = True, labels = W3_labels
ax.margins(-.20, -.20)
fig.tight_layout()
plt.axis("off")
plt.show()

# %%
# We will create a function that will take the dataframe as input and the filter params and create the graph and calcualte the 
# centrality metrics and display as output

def get_centrality_ranks(Graph, rows):
    
    f=dict(nx.degree(Graph))
    fc_sorted_tuples = sorted(f.items(), key=lambda item: item[1], reverse=True)
    fc_sorted_dict = {k: v for v,(k,r) in enumerate(fc_sorted_tuples)}
    
    d=nx.degree_centrality(Graph)
    dc_sorted_tuples = sorted(d.items(), key=lambda item: item[1], reverse=True)
    dc_sorted_dict = {k: v for v,(k,r) in enumerate(dc_sorted_tuples)}
    
    e=nx.eigenvector_centrality(Graph)
    ec_sorted_tuples = sorted(e.items(), key=lambda item: item[1], reverse=True)
    ec_sorted_dict = {k: v for v,(k,r) in enumerate(ec_sorted_tuples)}
    
    b=nx.betweenness_centrality(Graph)
    bc_sorted_tuples = sorted(b.items(), key=lambda item: item[1], reverse=True)
    bc_sorted_dict = {k: v for v,(k,r) in enumerate(bc_sorted_tuples)}
    
    c=nx.closeness_centrality(Graph)
    cc_sorted_tuples = sorted(c.items(), key=lambda item: item[1], reverse=True)
    cc_sorted_dict = {k: v for v,(k,r) in enumerate(cc_sorted_tuples)}

    ## use Python sets to compute a union of the sets 
    #names=list(set(names1) | set(names2)| set(names3)| set(names4)  )
    ## use the networksx vorterrank function to get a sorted list of nodes based on its influence ranking:
    names =nx.voterank(Graph)
    ## build a table with centralities 
    
    table=[[name,fc_sorted_dict[name],dc_sorted_dict[name],ec_sorted_dict[name],bc_sorted_dict[name],cc_sorted_dict[name]] for name in names]
    col_names = ["Node", "Degrees","Degree_Centrality", "Eigenvector", "Betweeness", "Closeness"]
    df = pd.DataFrame(table,columns = col_names)
    #print (tabulate(table, headers= col_names))
    return df

# %%
# We will create a function that will take the dataframe as input and the filter params and create the graph and calcualte the 
# centrality metrics and display as output

def get_centrality_values(Graph, rows):
    
    f=dict(nx.degree(Graph))
    fc_sorted_tuples = sorted(f.items(), key=lambda item: item[1], reverse=True)
    fc_sorted_dict = {k: v for k, v in enumerate(fc_sorted_tuples)}
    
    d=nx.degree_centrality(Graph)
    dc_sorted_tuples = sorted(d.items(), key=lambda item: item[1], reverse=True)
    dc_sorted_dict = {k: v for k, v in enumerate(dc_sorted_tuples)}
    
    e=nx.eigenvector_centrality(Graph)
    ec_sorted_tuples = sorted(e.items(), key=lambda item: item[1], reverse=True)
    ec_sorted_dict = {k: v for k, v in enumerate(ec_sorted_tuples)}
    
    b=nx.betweenness_centrality(Graph)
    bc_sorted_tuples = sorted(b.items(), key=lambda item: item[1], reverse=True)
    bc_sorted_dict = {k: v for k, v in enumerate(bc_sorted_tuples)}
    
    c=nx.closeness_centrality(Graph)
    cc_sorted_tuples = sorted(c.items(), key=lambda item: item[1], reverse=True)
    cc_sorted_dict = {k: v for k, v in enumerate(cc_sorted_tuples)}

    ## use Python sets to compute a union of the sets 
    #names=list(set(names1) | set(names2)| set(names3)| set(names4)  )
    ## use the networksx vorterrank function to get a sorted list of nodes based on its influence ranking:
    names =nx.voterank(Graph)

    ## build a table with centralities 
    table=[[name,f[name],d[name],e[name],b[name],c[name]] for name in names]
    col_names = ["Node", "Degrees","Degree_Centrality", "Eigenvector", "Betweeness", "Closeness"]
    df = pd.DataFrame(table,columns = col_names)
    #print (tabulate(table, headers= col_names))
    return df
